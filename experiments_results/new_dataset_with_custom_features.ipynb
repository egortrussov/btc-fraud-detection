# %% [markdown]
# # Random forest + fixed dataset + new feats (users + ginis + ext)

# %% [markdown]
# ### Feature importances

# %% [markdown]
# ```btc_sent_total 0.059242261959873255
# user_addr_cnt 0.056065621040674384
# incoming_tx_ts_cnt 0.052042665222316015
# btc_received_min 0.045571612263669084
# btc_sent_min 0.04422635405905365
# last_block_appeared_in 0.043100392149818326
# user_whole_fee_5 0.04159051941487359
# user_outcoming_tx_cnt 0.038600855085382614
# output_address_cnt 0.03831546944008901
# incoming_tx_ts_gini 0.0351494878952048
# user_btc_sent_median 0.029908543489398323
# incoming_tx_fees_max 0.0288455903630115
# outcoming_tx_cnt 0.02824856110482409
# user_btc_transacted_total 0.027356624807611994
# incoming_tx_fees_mean 0.02661688331388933
# btc_sent_max 0.025460300103577953
# incoming_tx_input_address_cnt_mean 0.023865338149391374
# outcoming_tx_ts_cnt 0.023661568650139863
# user_user_ts_fees_share_min 0.02359895593832743
# first_block_appeared_in 0.022529186703339567
# outcoming_tx_ts_gini 0.02179281863788633
# user_user_ts_fees_share_max 0.01927549000082061
# user_btc_received_median 0.01842787731682083
# input_address_cnt 0.017428907920491787
# btc_received_total 0.0158859882199415
# user_overall_activity_coef 0.015249959546381527
# user_active_time_steps_cnt 0.013958510812423289
# btc_received_gini 0.013190087500299773
# outcoming_tx_fees_mean 0.013080592477644221
# lifetime_in_blocks 0.012974351226350518
# outcoming_tx_fees_min 0.012761656284780614
# user_interracted_input_address_cnt 0.012626953403011424
# incoming_tx_fees_min 0.011471092367186752
# outcoming_tx_fees_max 0.008475338716418972
# incoming_tx_whole_fee_4_cnt 0.008176374184264737
# btc_sent_mean 0.008141775424791584
# outcoming_tx_input_address_cnt_mean 0.007854289754865625
# btc_sent_gini 0.0069453423218611724
# btc_received_max 0.005960350217984338
# incoming_tx_cnt 0.005700482927785467
# btc_received_mean 0.005600900151018072
# outcoming_tx_output_address_cnt_mean 0.005588224230693278
# user_input_users_cnt 0.004743984799466763
# outcoming_tx_fees_total 0.004614753989117319
# user_btc_sent_total 0.004229486725772619
# user_output_users_cnt 0.0034278103311474414
# user_interracted_output_address_cnt 0.002843886102173584
# outcoming_tx_whole_fee_4_cnt 0.0023789234925609714
# user_user_ts_fees_share_mean 0.0012756404250677282
# user_btc_received_total 0.0009515397631569375
# incoming_tx_output_address_cnt_mean 0.0008423741825148586
# user_incoming_tx_cnt 0.00012744539083311415```

# %% [markdown]
# ### Results by THR

# %% [markdown]
# ```array([[0.001     , 0.06850062, 0.99141531],
#        [0.02136735, 0.26663678, 0.96589327],
#        [0.04173469, 0.43359086, 0.95058005],
#        [0.06210204, 0.55595222, 0.93944316],
#        [0.08246939, 0.63310607, 0.92645012],
#        [0.10283673, 0.68555094, 0.91809745],
#        [0.12320408, 0.72490294, 0.90974478],
#        [0.14357143, 0.75656232, 0.90278422],
#        [0.16393878, 0.78193966, 0.89605568],
#        [0.18430612, 0.8012968 , 0.88886311],
#        [0.20467347, 0.81798577, 0.8800464 ],
#        [0.22504082, 0.83266844, 0.87169374],
#        [0.24540816, 0.84469097, 0.86566125],
#        [0.26577551, 0.85503572, 0.86078886],
#        [0.28614286, 0.86362568, 0.85220418],
#        [0.3065102 , 0.87164751, 0.84454756],
#        [0.32687755, 0.88278388, 0.8387471 ],
#        [0.3472449 , 0.89165629, 0.83062645],
#        [0.36761224, 0.89683944, 0.82296984],
#        [0.38797959, 0.90143737, 0.81484919],
#        [0.40834694, 0.90667362, 0.80696056],
#        [0.42871429, 0.9123411 , 0.79930394],
#        [0.44908163, 0.91955878, 0.79303944],
#        [0.46944898, 0.92362248, 0.78561485],
#        [0.48981633, 0.92845258, 0.77679814],
#        [0.51018367, 0.93176074, 0.76983759],
#        [0.53055102, 0.9372313 , 0.7587007 ],
#        [0.55091837, 0.94066318, 0.75034803],
#        [0.57128571, 0.94457547, 0.74338747],
#        [0.59165306, 0.94911703, 0.73573086],
#        [0.61202041, 0.95482295, 0.72575406],
#        [0.63238776, 0.95856698, 0.71392111],
#        [0.6527551 , 0.96346887, 0.7037123 ],
#        [0.67312245, 0.96692607, 0.69187935],
#        [0.6934898 , 0.9701888 , 0.67958237],
#        [0.71385714, 0.97431565, 0.66890951],
#        [0.73422449, 0.97664033, 0.65962877],
#        [0.75459184, 0.97797203, 0.64895592],
#        [0.77495918, 0.98072805, 0.63758701],
#        [0.79532653, 0.9835946 , 0.62598608],
#        [0.81569388, 0.98663697, 0.61670534],
#        [0.83606122, 0.98859749, 0.60348028],
#        [0.85642857, 0.99257812, 0.58955916],
#        [0.87679592, 0.99360767, 0.57703016],
#        [0.89716327, 0.99591336, 0.56542923],
#        [0.91753061, 0.99622642, 0.5512761 ],
#        [0.93789796, 0.99871023, 0.53897912],
#        [0.95826531, 1.        , 0.52343387],
#        [0.97863265, 1.        , 0.51044084],
#        [0.999     , 1.        , 0.47053364]])```

# %% [markdown]
# # RF + XGB (default params)

# %% [markdown]
# ```array([[0.001     , 0.01745766, 1.        ],
#        [0.02136735, 0.78188125, 0.88909513],
#        [0.04173469, 0.83075221, 0.8712297 ],
#        [0.06210204, 0.85089327, 0.86194896],
#        [0.08246939, 0.86262579, 0.85522042],
#        [0.10283673, 0.8719715 , 0.85174014],
#        [0.12320408, 0.87837187, 0.84617169],
#        [0.14357143, 0.88427734, 0.84037123],
#        [0.16393878, 0.88771239, 0.83642691],
#        [0.18430612, 0.89193227, 0.83109049],
#        [0.20467347, 0.89585947, 0.82830626],
#        [0.22504082, 0.89790245, 0.82436195],
#        [0.24540816, 0.90129738, 0.82204176],
#        [0.26577551, 0.90242656, 0.81972158],
#        [0.28614286, 0.90372272, 0.81670534],
#        [0.3065102 , 0.90526588, 0.8136891 ],
#        [0.32687755, 0.90689834, 0.81136891],
#        [0.3472449 , 0.90852228, 0.80881671],
#        [0.36761224, 0.91027988, 0.80742459],
#        [0.38797959, 0.91313504, 0.80487239],
#        [0.40834694, 0.91470821, 0.8037123 ],
#        [0.42871429, 0.91498941, 0.80162413],
#        [0.44908163, 0.91733333, 0.79814385],
#        [0.46944898, 0.91932458, 0.79582367],
#        [0.48981633, 0.91984938, 0.79350348],
#        [0.51018367, 0.92172264, 0.78955916],
#        [0.53055102, 0.92301415, 0.78723898],
#        [0.55091837, 0.92524644, 0.78399072],
#        [0.57128571, 0.9286108 , 0.78167053],
#        [0.59165306, 0.93021324, 0.77935035],
#        [0.61202041, 0.93190661, 0.77795824],
#        [0.63238776, 0.93359375, 0.77633411],
#        [0.6527551 , 0.93597304, 0.77331787],
#        [0.67312245, 0.93672316, 0.76937355],
#        [0.6934898 , 0.93861893, 0.76635731],
#        [0.71385714, 0.94018317, 0.76218097],
#        [0.73422449, 0.94124424, 0.75823666],
#        [0.75459184, 0.94454123, 0.75475638],
#        [0.77495918, 0.94603267, 0.75243619],
#        [0.79532653, 0.94766245, 0.74779582],
#        [0.81569388, 0.94979204, 0.74176334],
#        [0.83606122, 0.95308271, 0.73526682],
#        [0.85642857, 0.9546837 , 0.72830626],
#        **[0.87679592, 0.95633456, 0.72157773],** (BEATING PAPER)
#        [0.89716327, 0.95856698, 0.71392111],
#        [0.91753061, 0.96222222, 0.70324826],
#        [0.93789796, 0.96516927, 0.68793503],
#        [0.95826531, 0.97174571, 0.67030162],
#        [0.97863265, 0.97951254, 0.64338747],
#        [0.999     , 0.99952107, 0.48422274]])```

# %% [markdown]
# ### Feature importances

# %% [markdown]
# ```[('user_outcoming_tx_cnt', 0.11130955028031533),
#  ('btc_sent_total', 0.05754340572881059),
#  ('incoming_tx_fees_min', 0.050100039655149094),
#  ('incoming_tx_ts_cnt', 0.04161536448826865),
#  ('outcoming_tx_cnt', 0.035048725659737476),
#  ('incoming_tx_fees_max', 0.03473002820495089),
#  ('btc_sent_max', 0.03393465671281762),
#  ('user_whole_fee_5', 0.03092312123854444),
#  ('output_address_cnt', 0.030206489739152388),
#  ('btc_received_total', 0.027354015069021853),
#  ('user_overall_activity_coef', 0.026893872200473463),
#  ('user_btc_sent_median', 0.02588409182780415),
#  ('user_btc_transacted_total', 0.025006823710830052),
#  ('incoming_tx_ts_gini', 0.02459342665538105),
#  ('outcoming_tx_input_address_cnt_mean', 0.024193929072440078),
#  ('outcoming_tx_ts_gini', 0.022034084716407935),
#  ('input_address_cnt', 0.021620890095254745),
#  ('btc_sent_min', 0.021018767266531867),
#  ('incoming_tx_fees_mean', 0.020832131508788786),
#  ('outcoming_tx_fees_max', 0.01979862348104316),
#  ('incoming_tx_input_address_cnt_mean', 0.017823422819703814),
#  ('user_addr_cnt', 0.017715719342385694),
#  ('first_block_appeared_in', 0.017584606920667885),
#  ('outcoming_tx_fees_total', 0.01720484893005958),
#  ('outcoming_tx_fees_mean', 0.015957922384072017),
#  ('user_user_ts_fees_share_max', 0.015466572282478023),
#  ('user_active_time_steps_cnt', 0.015175941259100925),
#  ('last_block_appeared_in', 0.015056169132900445),
#  ('user_btc_received_median', 0.015030529598905116),
#  ('user_interracted_input_address_cnt', 0.014581188068418833),
#  ('user_user_ts_fees_share_min', 0.013881317311903287),
#  ('outcoming_tx_fees_min', 0.013472152579524221),
#  ('outcoming_tx_whole_fee_4_cnt', 0.013057197760194414),
#  ('btc_received_min', 0.012210928827258102),
#  ('lifetime_in_blocks', 0.012054223536972879),
#  ('btc_received_gini', 0.011174084993192073),
#  ('btc_sent_gini', 0.010041306327190722),
#  ('user_interracted_output_address_cnt', 0.008943161552316782),
#  ('btc_sent_mean', 0.008822364814240546),
#  ('incoming_tx_whole_fee_4_cnt', 0.008074375602074645),
#  ('btc_received_max', 0.007376260254788923),
#  ('user_input_users_cnt', 0.006096720549042197),
#  ('outcoming_tx_ts_cnt', 0.005881271364805249),
#  ('btc_received_mean', 0.00501421879738069),
#  ('user_user_ts_fees_share_mean', 0.004665340332054409),
#  ('user_btc_sent_total', 0.004574881078060048),
#  ('user_output_users_cnt', 0.004272019784702456),
#  ('incoming_tx_output_address_cnt_mean', 0.0011850759427960973),
#  ('outcoming_tx_output_address_cnt_mean', 0.001029701297810286),
#  ('user_btc_received_total', 0.0008676969577004557),
#  ('incoming_tx_cnt', 0.0006469000940354978),
#  ('user_incoming_tx_cnt', 0.0004198806668039452)]```
