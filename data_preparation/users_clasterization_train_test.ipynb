# %% [markdown]
# # Кластеризация на пользователей

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

sns.set(style="darkgrid")

np.random.seed(0)

# %%
# Out:
#                                     addrId       txId  Time step
# 0       14YRXHHof4BY1TVxN5FqYPcEdpmXiYT78a  230325127          1
# 1       13Lhad3SAmu2vqYg2dxbNcxH7LE77kJu2w  230325139          1
# 2       1MAQQZn7EHP6J3erXByCciFiVcgS8ZhWqz   86875675          1
# 3       16zs5SVSyADh5WrLNbZbpRLsBsN5uEzgeK  230325147          1
# 4       1QJpwtUorBKPGUJkSyrRcBKTAHq4CXrdYh  230325154          1
# ...                                    ...        ...        ...
# 477112   1HdnGvuc21Y4QfBEHUc3NFRJhGywdSFUb  157659046         49
# 477113  3MfN5to5K5be2RupWE8rjJHQ6V9L8ypWeh  157659306         49
# 477114  3DzbpEogZ1mn9FgCHcmzYPLDbV9GuxYHpi  157668825         49
# 477115  34yD1sQg6C16aANCtibYXRj5NsX6tt4v5R  125788182         49
# 477116  1JERHCgwHG2Z7T3KjNpEwj3fJNX8vSfCX2  157670868         49
#
# [477117 rows x 3 columns]

# %%
# Out:
# ((323503, 3), 263869, 400212)

# %%
# Out:
# ((146321, 3), 136343, 400212)

# %%
146321/323503
# Out:
# 0.4523018333678513

# %% [markdown]
# Сделаем маппинг tx <-> список входящих кошельков

# %%
from collections import defaultdict

addr_tx_df = pd.read_csv("../dataset/Elliptic++ Dataset/AddrTx_edgelist.csv")

tx_inputs = defaultdict(lambda : [])
addr_list = set()
for index, row in addr_tx_df.iterrows():
    tx_inputs[row["txId"]].append(row["input_address"])
    addr_list.add(row["input_address"])
tx_addr_df = pd.read_csv("../dataset/Elliptic++ Dataset/TxAddr_edgelist.csv")
for index, row in tx_addr_df.iterrows():
    addr_list.add(row["output_address"])

addr_list = list(addr_list)

# %% [markdown]
# Сделаем граф зависимостей между адресами, запустим DFS и разобьем на обычные КС

# %%
addr_to_neighbors = defaultdict(lambda : [])
for tx, addrs in tx_inputs.items():
    if len(addrs) <= 1:
        continue
    for i in range(1, len(addrs)):
        addr_to_neighbors[addrs[i - 1]].append(addrs[i])
        addr_to_neighbors[addrs[i]].append(addrs[i - 1])

# %%
from copy import deepcopy

used = defaultdict(lambda : False)
addr_to_component = defaultdict(lambda : 0)

def dfs(node, comp_id):
    used[node] = True
    addr_to_component[node] = comp_id

    nodes_to_visit = deepcopy(addr_to_neighbors[node])

    while len(nodes_to_visit):
        nei = nodes_to_visit.pop()
        used[nei] = True
        addr_to_component[nei] = comp_id

        for nei1 in addr_to_neighbors[nei]:
            if used[nei1] or nei1 in nodes_to_visit:
                continue
            nodes_to_visit.append(nei1)

current_comp = 1
for addr in addr_list:
    if not used[addr]:
        dfs(addr, current_comp)
        current_comp += 1

# %%
list(addr_to_component.items())[:1000]
# Out:
# [('3ERqtBuTkehxuKaMjRghMgkZbL6QTGsAgk', 1),
#  ('1MvrNMPgAqc9M5uRedjGTHaKQ4yWFSSBb2', 2),
#  ('1Nyga8W7K8AWtCECGYnJgTpEiikd8gxtZU', 3),
#  ('127YEf8HFGb26bk7Dk8HAX9AywevCuYNjV', 4),
#  ('15c8pksxYhRwKYQDUkYveTyGNvpJ6MNVAX', 4),
#  ('16W7H1u5oajJVCPoKCm1boQHSrv6yANVZr', 4),
#  ('1GhW8xuMt5nZ2LPptYkJBRpxLBvq6YLwUH', 4),
#  ('14PJ3ZdE5GigS2jxn3FM3BiTBxrbJZoRko', 4),
#  ('1JyqaPFquMib3te2iFmAxxSoXUpKr5cjAn', 4),
#  ('1Eowd1eWu9mca2e4YFmjQQqA3HHpsn3geG', 4),
#  ('1GLK8HoHmfCJe9cWEw8JvxFytfcMZA2zuL', 4),
#  ('1CnxggyLkQjsxeKe2sKrPXv516acznY3Eh', 4),
#  ('114Vpp1rW5VVqjDaHCokA3WBFGQZisQHLY', 4),
#  ('18LSE19xt8mNbk3B5RXFQaYmE9Cbo8f4Xd', 4),
#  ('168tQmk875m6S5XUdf1sgD1GU9L2SstGqM', 4),
#  ('1LJ1rfY8E3aUVi4m7QpFN6kehF2cv77bA8', 4),
#  ('14tbpvCUTXV9D44aahJU9fanmLP3roiDNN', 4),
#  ('19dRrQMHpsgTni4gUAdTs3d8mTqoJUsWF3', 4),
#  ('1AYbvgKBcJtj5FpHegVoH97qWbcB1xGEb5', 4),
#  ('1G3HhfcymCrm8wFMSmR1wrBZZsjwYqHaWm', 4),
#  ('1Mm7HCGYV1m4uvS2QycZkMEcx87iWZFxKW', 4),
#  ('1K7PJQwSB4JQbxf7FL778f99r6aRzm7M4n', 4),
#  ('19LM8Qvu5TUdJdyLvAGhBSzDiuSrkDA2ZQ', 4),
#  ('1J7mFSwfKGXYh2rpPNXvSexDdUCU25YkH3', 4),
#  ('13FtU4cDiBdj7h6T3rDZjLKExbEEg5WxkH', 4),
#  ('1AxWb7Pac4ptxqNm23T5WrddRUv9knaVMs', 4),
#  ('1LsvUGstKjYFugyejQA3AhSgjVCF8qVBkd', 4),
#  ('1HEsAxpxLiebUkZuDWmwePd8Pv5AZEjt5J', 4),
#  ('1BFZN3yJMFPAc6VEPvJSFee8b3GBUwDAvB', 4),
#  ('189ZLkix7Rez7JqqwCHuQ8mzrPfhAqZyGG', 4),
#  ('17GdKN3fppLGikEYsPRCfkh892DXyZSt8k', 4),
#  ('1CcmtwWNe2xa2p1fdjzRzcikM1BvN55qTd', 4),
#  ('1FH1yRycc5zH7WWndkYw9oiUKgsUu11JzP', 4),
#  ('18zA3Nd5TioozY6waf74VAPZ9iPhUZgJqt', 4),
#  ('1K9Q95fhHapTpYkshSJ9ra6Z45n1MPM5TK', 4),
#  ('1MLHU1aFdjWXFcFc6HoD2TU8Xni8zA2PXX', 4),
#  ('14wuG2nDdpwwPtyut3QfYyJpk7PMDijSaw', 4),
#  ('1MZzRZpLN4mH3fSe1uWEF6Nx2X7nvD2YB5', 4),
#  ('19xrR25h86NV3YsqjqnFXigQv69cFkc6ab', 4),
#  ('1JotifPNwCUMX4ygJ94LcqpiJtUM4oTyTh', 4),
#  ('1HRvMMX8tTKRfXzmmwYCWuEf3bqpUvp3mK', 4),
#  ('163S6cbhhvYkjovPmUbpCj1wr8Ehx6wxqP', 4),
#  ('1PVSWEc9CoL59ZzexxyAm9hGjBdZqtMkLR', 4),
#  ('184yYSktmsQFheWjeq9LgEsZJHXJ8rR4sX', 4),
#  ('1HbQo7ckz53Jyv18UFrti7eL59RQYfGsNk', 4),
#  ('1FRQG6E2rTYGpMXEeCyWzQ1PWroo5Xhj4U', 4),
#  ('183qm2TxFHnf1iQPUKRFqG4ivHKxRUdv9D', 4),
#  ('14UNcKz9vGdz5SSvwYee4KC5N16wEBCqQh', 4),
#  ('16ZbfHHDA9n8PjheE5iLrVmf89tsfcAHJo', 4),
#  ('1C2rrwanG4U9q2cSPBAn3QdotK23cAhk8Z', 4),
#  ('19ZK3Vp53vwfiwKzXV1dBn39SKzSkEWHYN', 4),
#  ('1AqDZqZYHodC61BSgd2off44jRVfcCqm7g', 4),
#  ('1MNaL5pmF1owVNAnJtz3Xg4gsAhkBYdbbg', 4),
#  ('1Ay94SeYxtuoCSDU7n4icpQjZBvDJseA8t', 4),
#  ('1MKPafwEW3jcp1e3DYBaeYECF7Mv2wZEog', 4),
#  ('1Hv6mFhZgjYAErSYkxBRNGiwWk7P7584fB', 4),
#  ('1UiAiv9d8DiurWZFivppwcvjk2Z6UiN3t', 4),
#  ('1Fx6wGGeaEgup9HCXJL8JXHuVqH8wFVWzc', 4),
#  ('1JzozTHQgjttdiGKX71ZWcPjrw43NmzpKk', 4),
#  ('1GekDjsyH1CXB6pUvmXYGZyiNkgrpepZkK', 4),
#  ('1ASMUg9t5Z2kqmUFKhGBuENsGVAUqYgCHL', 4),
#  ('1Kk1TEKMTK1cJy6xqA3ySBckHQxgkkUf7o', 4),
#  ('1u9MS9ykESWKz4bxDoMg3RyUopQijiuBq', 4),
#  ('1KJVYgzi39MeQy2SN8SZ3MVHDjwAf8xxed', 4),
#  ('14ZeCWRweT6sboWFf3soLverDGnUAHpYNk', 4),
#  ('18Si9bJfn1cy1iSDqdXhK8DYxBPV1JeRLk', 4),
#  ('1r2Ge1aPEBDEPJX1qXHVk349RruQwuS11', 4),
#  ('1JpVLXigzhqQqjeVYbKXpfJ7cuS92jGJog', 4),
#  ('13HVa8wjg46ucf2DqEf4hCzcKyQKZujkgN', 4),
#  ('1H2NvUvVRrCgMvh2Um6nQTcqHCDqw5htCf', 4),
#  ('1JjCGQ5JDgVUDAEQVKxv6iCGnj2tGxmoj5', 4),
#  ('1E9cP4EBfew8d4eX95HMC2oxT8nJgDH2vW', 4),
#  ('1HUe1wTDQDoGMKGztxoET5999EXZusxhdy', 4),
#  ('1CpTHpCMBzFd3PuLy3q6LN7bpmVtukp3Mw', 4),
#  ('1PvKwjDAmXMaXZd62R5GGjvSiuAJ7CigPn', 4),
#  ('12bbxHnzzt6tN6cF7gwP5mdGrPqUoRg5kS', 4),
#  ('1Jcprm7Yjhbjns7zaFiKaG2ZY7v8BC7zu', 4),
#  ('13yf2x6k5gNkEMwP3LmRuB95PLgZM8VtEe', 4),
#  ('1G8KW2Rx9y1jVwDSemxW9JAWbJBM4nHNcd', 4),
#  ('1KGDR5CTUZpgZToKxg2W7GiWMpuYMgBt7t', 4),
#  ('1M47pG9X2Lmg3R8sstZWieXgJkZTYNX87C', 4),
#  ('1KiD9wncNfX8A69N1T2oCxxk89jzPevGvJ', 4),
#  ('16Q1TrbPLw9u7sHyoSwbrkrWgCRorS5HCP', 4),
#  ('1ACqmmZ7k4Z9MYT6o2KHHErhYaTxLWTUAf', 4),
#  ('1Ms6KJxWxJVEUex8mCec5XawqK5kT1BLBm', 4),
#  ('183zFUHi3HC29jMwp5g15JRNw76BYpTJsx', 4),
#  ('1LuCwQjFixDkSSYQC75QRtjnnsJvzMc2wg', 4),
#  ('1DShXrEuzkxzH49GqwF7GjxseSTgujXMiG', 4),
#  ('16PQRz3fDNGHnTkmbaL6cEAu5Lu5Vp9qvH', 4),
#  ('1AmcXmC6Mreo8Zsxj69ChNcCru4Xn5azHN', 4),
#  ('1HWDfUEnocuCUf93wqHFuUYpFT6rXSs1TA', 4),
#  ('1Pskmkz4N3PYfhWkD2YHvgK311XLvnYMK2', 4),
#  ('15gnLk3RCQAbLkQVCnwo3MeMYwn8Hvb9Be', 4),
#  ('1EHLHjdTMcxTzJx8Qe6krj8z78YZ9SskJQ', 4),
#  ('12kbbJpsbAzub6Bd49xsXjuSKLwH8yLKUi', 4),
#  ('1MS7tmsLVCncgJUhzjL1tAUVwm5CLz6g15', 4),
#  ('1Fd9t5fov5uea6knt3SqcwgJEAKYKXTbW3', 4),
#  ('1JfaJ2kS3nXG6DFmxaExbVdX7U8fudRot', 4),
#  ('1LMvynmU1tFPeeXwSQa5wmKyYokqdHs7KP', 4),
#  ('1PbDRuGsvcogBMa9EED88SnfqigYRxDsky', 4),
#  ('1qQSJoYLY25rzZtfC6xchpcUAFYAbxFwj', 4),
#  ('1BYGhRaZG7J8aWRUdfm4p6ScCgY2DNg92A', 4),
#  ('16atiWeXqdKKoxs3m88kYf9p1XFNc9uq6d', 4),
#  ('1CafbCGRuYqtn16ZFRoqx1pEe4kTGy2Uy6', 4),
#  ('1HrPreii64gA9zswvzAs2QHbj7pYraanQA', 4),
#  ('1KwK6SD64zNPh8SQnbeDooE4oDjQzFyTZ7', 4),
#  ('19eZ3swmq9Hz47WUpWxK693gHipcypmJ9A', 4),
#  ('1ATbPQEhJwDVEEDycPnA83hrvjwZhT1r98', 4),
#  ('1FfAL291kKGhTzJB6XH7A6hBneEDKYbU3M', 4),
#  ('1BAGRm3dgZb6f1bHVbUXTZZhKWMZtpbLZs', 4),
#  ('1JTg5GJRHkchwPL88FFBHNZfw7fwHQTCKs', 4),
#  ('1PV7BDBayKmG9m8RqsH7Y55xtr76Tiygme', 4),
#  ('1p5dJQxQ4aCjemsGfU7zKR9tsdNin2kmr', 4),
#  ('1NhgyPw3ZYFjSfeydkUhWpu5H58CJ8Cbu1', 4),
#  ('114AtcBq8KwHg5tQMqfoycNBLMLJ1B4j8y', 4),
#  ('1EN6VCx75PrmomYhLHeWyf7NnDYe87XNtk', 4),
#  ('1MEVyncd75e7DJz97LhTiN5Loibbrc9Zkc', 4),
#  ('1HjdSsK9G1FVXuxhJUaNiZkYvfdWEWfdV7', 4),
#  ('1Dajw1762nsrdrp5ycetVCeCrECs7uALXo', 4),
#  ('1KAaeknhkRQtDvJU88VKyyVSHHh8fGunBk', 4),
#  ('1KWPp1fHXNcbPtXGxbhZFgHZZER2Z9tEFK', 4),
#  ('1LEYKJkieACogDjXRJgJKbxcj2yUWQJ4ue', 4),
#  ('1PAjDkCCyNgydJxX3GgRV3iRKC3Kd5SGWE', 4),
#  ('1KjJMBpqcbUDBeak4xdFqPGDJEZJrgZZD6', 4),
#  ('16pKSgvvsQLhRbVh1TPokv3hqnKmnkdot9', 4),
#  ('1LE93qjyhTA3tkhZZeDNCWtgHGiBHKH18x', 4),
#  ('19hFHAd7WNHJpUWVPMQt6eSoZ835E9yeDt', 4),
#  ('1JEiR7wcQASjsPNTtSAQaeWR8ZJLpGP3Yh', 4),
#  ('12rPuf5GJJpMhdERu5BiU6LP3yjXUfhwaK', 4),
#  ('1MmE4gLk38W7HXFfA1jZd44JBVi9BTFjdi', 4),
#  ('1C1f9pQGj8HnCAjYmZ5bWUP4MPxBESiyth', 4),
#  ('1L5Vrk5WpSTGPLQZJMrZAXuSKPvU3ie75K', 4),
#  ('1FLj2pCRar6MUr4KyBzP3YAwd8Ejh79ntv', 4),
#  ('1DtSUJdez471qfix4iLeTrHmsJ1g1QpQdb', 4),
#  ('1DKXCzq47pRBmV2xHEoDqewnGD5Cgg1DKx', 4),
#  ('1AxLaHYZwFW3figERWzERjxX1pBF719Kgz', 4),
#  ('1jqR82xMDbfBSbVZLcWfwXCVDG8s56XtG', 4),
#  ('16aA6gvVa5ffcPLw4KUAySAtckJ4PHTtZt', 4),
#  ('12pznj8Z7VBxcxSfrmMF4W9a5XSVR59dV7', 4),
#  ('1dc2yztJcP5jAjKoWaAiGWGyrK8mxMdbS', 4),
#  ('1AwWwE5WwEhpbJUDTrAdKbe8Mj243JutSD', 4),
#  ('1Fnb74m6KE1LunEGvzTwe235YfroLApomj', 4),
#  ('1PRfFz6S9hf2Pjki2Cx4B7gBiSXPKU4yMu', 4),
#  ('1DQAMnbK1WWvH3pFvuvHKSaQWoC1atG7J2', 4),
#  ('1F6ocUsCEMTV1sFiy6Hj9PT5TA8xNraDT9', 4),
#  ('1QB2AvuN1JYz6EaJZEAU61n29vDNHcBtU4', 4),
#  ('1CYPWBTWQfnEm19CG83EHZQgnmBzP4kd3G', 4),
#  ('1Emgt6DB2i8hQ7m6uq952n3REQasJyM7kG', 4),
#  ('1Hnv2yrrLJQcUkTbhgMYXMqtn2yBCXRK5i', 4),
#  ('1Gh5EZCK9YgUeS9qivc4xh5A2mkSH8qiKd', 4),
#  ('1GGMS23rBK31qTAYy66MKZ2vMwws2ivc72', 4),
#  ('174edcZoxp7ryvQpn24JM6NQLpXjDBxKrY', 4),
#  ('1CmX9kA4epD3E1Ay477tsqTpcPtNN8sJnj', 4),
#  ('19Wag74r6WAffa7vJktTTM7Y3RSRwpKWHr', 4),
#  ('1H9YUmf3PR4cV2ionu7PmGioHAQPGmUabo', 4),
#  ('1DMBiFRVvs7ae55Txj8kJfRf5eN2Gz8Rv5', 4),
#  ('18ZVQCF6MxBzr7JBu8F5zvSP3w4A7CSV6h', 4),
#  ('173AMU2pgy6xrKogttft5ZZ6jnbs4Vd1sL', 4),
#  ('17p8vuaoQanu9TBTXpWzvQ15JS3WLsDR9Z', 4),
#  ('1GNbrWZcTXEnzERAC1jnJBo5hzZ2oKPHdC', 4),
#  ('1DaTDDbjJV5nBJRDojUb2bYGYAtzYNzbqn', 4),
#  ('1GHtASU2RJm6krFFXDMkMY4MPgXA9iTG7n', 4),
#  ('17nahffeRfbFXbvuGRxYZ8NVTzuYNWHNy8', 4),
#  ('15PY85m5TcTSNM5voGVBio5khDLcwXRwqM', 4),
#  ('1jZZHXLHpKyundv9E8ws1vDzvfA222bXy', 4),
#  ('1M5zSy8LBwxpEbLBEmNXt5XWd2JAUH6ajm', 4),
#  ('1DvfyeJX7zv96gZbx6vmbiYRpTQvp6bhEN', 4),
#  ('1NLKDU95cGQtfvWDkf3Kfr6yf3NjCHDrZi', 4),
#  ('185sWh6AZeeRaQj7dFnNzMcgjjwbznYaEs', 4),
#  ('12FZVfqvf8WrwsWRQKoL4ZMJoVte1P4s1m', 4),
#  ('1BwwKHGWqf8rC5GJXEFyad1oAA7hVKWQ7q', 4),
#  ('1NME2mWMvQDC7TptJuN2e5h3h4mkKEC1WL', 4),
#  ('18FRsDzVpWwsQmFiP2Kihd1q2sS7grFLvr', 4),
#  ('1uZ4DpmWniQ7JRNzYPNLJM5gYCkwmnkVR', 4),
#  ('1H9BtesWGmFmyDmo8FN4t6gWsd1PKZWaEN', 4),
#  ('1Gk44qYfF13PB9P5pbLsNSCeHYdoCSoLNr', 4),
#  ('1Et3sKi1HqYwHHdtpyLSrbmhZBVcg1guj', 4),
#  ('12APNvMStGyWukxTY7GrJY17aBhEfigxTZ', 4),
#  ('1LrH6EwQG2YwvuyG36XYAEsXmKn6MHXxxw', 4),
#  ('1LvZD5B5MMhRHQPN2ZjVLMkD85yCmgGXoL', 4),
#  ('18oaEeCyPJ7zY6EPbQRRyPGbYa5U6Zs3ra', 4),
#  ('187cR75aTUu3nsEyAFGd1sgpE8AQjfWpB6', 4),
#  ('1FVD91yNSLsM3vsbwcEJ3j1gj6XuDNgGiE', 4),
#  ('1qhAW9dS6WuGNcooiQMRaAUs3ggERNoWv', 4),
#  ('1PoGeQAfHFRugSSJnDDqC8Uvnr47XK2bzj', 4),
#  ('1MdhUE2AgKtu5LQgX4zXnNSaQ5p7hDpdXr', 4),
#  ('1JRTc6byiM6GN4xW4fzzL6NLijgE44U8i4', 4),
#  ('18b81jCQjhZMCA1o4q1NWK66q5iNrxUCFG', 4),
#  ('1PPfe5eH2vkrBFK9DW39EgrBhgS88jRt9V', 4),
#  ('1PYnFqnwYFEZBzrznizrhsUWdr7dSELEM5', 4),
#  ('13vzJccpDHZxHJFD3Hm9wo48W919St6Bn1', 4),
#  ('1HieoaPjJEGtCK8EVsyiQHiPuW1DeYxqF8', 4),
#  ('15pmusDvME1eTtdwMjta6K66fYJyJ6Bnvd', 4),
#  ('1QAivFBbT9cFVriPuUREUc9xkhmkokjFKt', 4),
#  ('1B9e3z5zYrWsbJf9dNs6nVbxBgQHQmTqJx', 4),
#  ('16Ak9Jyw788acVtz2Ek8xeR8TRLh4Pa8bx', 4),
#  ('1CgX2NmBifZSKCCn8wr2uB5xhF6JLqxrop', 4),
#  ('1G51LC8q94XTGbofdYMkcLBu7DTh1pJBo4', 4),
#  ('1J1P51Cxps2rtAGg4USrRFBvQzsLjtiACq', 4),
#  ('15oL6GWedqyEi8ECnVkm8UZLLgJ2xudpJX', 4),
#  ('1PFFz1irdcwm8cmNDkTK9jhMCaFkcJex46', 4),
#  ('1BYrj2Yok2223eSs5GT2GKwAogKnitqYvn', 4),
#  ('1Gxn3tHUT13PshBCEcKrDf7xeU3v1E97Hr', 4),
#  ('1VFAW7KBxMkacpTxMiZCjEN3qHNWCZShk', 4),
#  ('175nV7DwJjubECR8F3Wkk6ba7epPM2mbmn', 4),
#  ('1DNCxzFqucLvQM6AfygFofg2VXto9rDNW9', 4),
#  ('1fmtKxyGqgq6QjYjSvhheuoxNDUiW4Ecb', 4),
#  ('1Lookv3pdrfJuchXtcoyAAAJrJ1TThHbkw', 4),
#  ('1CEQsSyPBoydrkQXZ7doykXUGnFuVaEQgV', 4),
#  ('1FzWTiHow8JyhbuM1m1gHRQrfBcSWvkrJ1', 4),
#  ('1JbCwJibuXsUfQnMSDNLqKjtAHcZoFEBWy', 4),
#  ('1P8Vvu77MjgQmK6FiyajyYU9LVEhtqAj3S', 4),
#  ('19trFacLkLacGKT8DismFgfmzzq14nvHYH', 4),
#  ('18pdVNhTpFdUCrTqcHTrDjEsUM1X4JmDkd', 4),
#  ('16ueX2QQyWuV1KKSHDqQUg4LnimeZEMZwK', 4),
#  ('18wEjUp7XmprZ6HfuLEFh5Mi66RbVHnw6L', 4),
#  ('1G2WHx7c7sJ266nF4enxUYNctqL7fDwFFh', 4),
#  ('1CKhmQixszSR3ibDCrExUYhe9tNfuRFEye', 4),
#  ('1PtgQTkKPKenckrkazheyn92edWYxEjM8h', 4),
#  ('14n5nx1EzATmLdyNVebLQTkiz4pLkgJkbz', 4),
#  ('1CtXvL3Qxwi2jvjVhDodU9uaY5PfqTkUQu', 4),
#  ('12vqrTj3b5Z9mQ2PvPmnfCbviFtKKGou6s', 4),
#  ('1QJdLRfgcE3M3ZnFW1xEVwvDfnHPmna38A', 4),
#  ('13GV6SjdArRU5cafDvK7u71iS43MGFHoie', 4),
#  ('16woeKsJRsYTRUiUDUCdBg1Whw47SDanoC', 4),
#  ('14a8sicaqyRhZF2xXViemmpoDnyAvW8T9g', 4),
#  ('1At1o2XhjWMYuQy2UyWRA7p7KsWpLLmcmF', 4),
#  ('156mg3aBtiQjh3NzLcAndjMDX4mWF12KbU', 4),
#  ('1JCic8QEWYf5Qo21bdVHbQ4NMVztPoRkJL', 4),
#  ('1J2TD28tppd5sKnnJr1eY6DoyyJZitC3kN', 4),
#  ('1DJ6ssZ7kn4hLoTT7d1NS2zpfHVH9L6G7v', 4),
#  ('134Qxx1xYdBzAFZRhySQsgYhmJgzEqAfwd', 4),
#  ('1D6KaVFpHt8438t6g9uoV7JYqqpzq2YcS9', 4),
#  ('17AgavGbXJJoLsoM66MGYK1CzNgAbh7qLS', 4),
#  ('1D18ZY7iWnJpsJukNWNoEZrh4ohC1J8or5', 4),
#  ('1FPsS2Afw4SEsMxFq3Ttg11E9LXvLmCHDj', 4),
#  ('13gQYxMH5h3An1NxjYBAdnjpDkwR5T5GSa', 4),
#  ('13DiSMUQmRQM5Qh9cBokHrab9mE1iAEdsJ', 4),
#  ('1542xNScDKash6YKNDf5Mcmy9bdbcVR41T', 4),
#  ('1AY4kb78hyHkmiPcEXeEH2uSnPjET2KKSh', 4),
#  ('17f258VXR4F1Ayst6zeF2ypbMgLwNA5pRw', 4),
#  ('18q4yrfW9MpnvDT7zJvsj7KHHeVv67yDJb', 4),
#  ('1EALnKx2ehSrBEqfRnexGGTE6kpoAWeF4v', 4),
#  ('1QGKZn6gSTpzrJ6Dgzz5jL2r6SJymWjy3V', 4),
#  ('1BnQXe7R9m5pdPC1ASaCdK7tTybSyCEpPW', 4),
#  ('1CtJntn758UgBjbZTo33P1oMKrtD1CtTUa', 4),
#  ('19LkkPFjAwEfGyfZ16Hip1EJGnfPk6YbPs', 4),
#  ('17Nb6tTzeHQUKkctuvSpi65V6Q85w23pHQ', 4),
#  ('16uG9HWj3hqyyg1cXLN8oujgtFws6QxZyi', 4),
#  ('1NLo8rX7szge34zYD18gbV8cKZjV8LUquK', 4),
#  ('14iGcmf31YSbKL2meA1UUbFpMjBoax9frB', 4),
#  ('1KgbkqdFBFBkT7HAbmdVg6EcBdjk2uFwNy', 4),
#  ('1837ms351fYfMNLkyt4DmH91XRd3hDHWfR', 4),
#  ('1ChW9v4Ko8L7Rhjshy4mo7XiF3W7KqRLu4', 4),
#  ('18kC7jE7EdPZ1VARWPjpDzDc3ZNNWgT6Pd', 4),
#  ('13t2YuXLVZA62Bw22Fsm8LAH7gtrioQNeX', 4),
#  ('1Mocnau8VU8sL3cDYWc4JniZrmrUPCjN3x', 4),
#  ('1C1tRFLGB4pQ1wjKihWoNbNAY4itGBs5Uu', 4),
#  ('12w38KZwuRiinisya8GL8yMDjJan31FodW', 4),
#  ('1Crn1U6vEiyALYMZPmCmk1nZpDuaDAqHTg', 4),
#  ('1C8XgoFawg67rocsgFod7yi5Fyo1zyP39P', 4),
#  ('13ZgqXUYBytj8Wwwc8kT3qL1TrpKcWwUEL', 4),
#  ('1LxgdqduBKfkc5nPWSjNwwgxLYsCSMskbv', 4),
#  ('15DULMgLtstSMuZE4dn3j7RuzKsrYfh3ET', 4),
#  ('1MHcWGedGHxB4Mmhw8W3tcLZQiGwFz4hra', 4),
#  ('154N69QJGriHDe7mdCqexBU7m1j9TyhWTw', 4),
#  ('17SFmFadJEfk1Gqufora9euYcqT1sVqd7Y', 4),
#  ('1P56sWWJEiDcydGydDWmwLPtwETepqWjm7', 4),
#  ('1F2kZgNtGmFyppvyRYf6Lq9EVUQAruoZGE', 4),
#  ('1MgaiypZkLQsFgMDpU5joo99mRYN5Y3VYq', 4),
#  ('12Ro6ktD2bfhC9jdAd3QENykqCFvL55kHT', 4),
#  ('1MzmeaDKo5rfRhGv5tcx1ynvRKPzhJ9gZs', 4),
#  ('167b8ruKeZfcSKkw8AXGS1x5t62CnXbnPS', 4),
#  ('1H4wuVhfRdPxi59H6xobkae13W7DWPrXSB', 4),
#  ('1JJ5QBWB2ZWVmKGk5y9WKNj6BUYw6e6CzB', 4),
#  ('14XKFoTN9ZGktHL7m9bc2Vhzvjsh1r4wpt', 4),
#  ('17J9YYFdTzfDJzoDais7aujJXyuD37Atfo', 4),
#  ('1JQZKoAhT264dfKHMw9zeFjb15rgtK46Wu', 4),
#  ('1jyfZGZrEXKSkFgHwXgvCFCvRhjJ2pBJt', 4),
#  ('12KCXDjWSZj7JWVqkbu5YeTyfNPQjjp2uA', 4),
#  ('1QxbrbNQGzGzrvNgCwD7FncbK8oa6CRD1', 4),
#  ('15GpCNakTmHCrFsDQQxsY1xgGfUCsN2MpB', 4),
#  ('1Ak8bxHYsYLNFZFceYZY3g5BGULkKHAC3A', 4),
#  ('18j7NuKyBsmxFgfwKJ8hq43jSHfmpsSd1r', 4),
#  ('1D2AvavK4vFbZQk6LXT3y3Hgw9VBRaBoxj', 4),
#  ('1EMLJfVxTCaxLiFi898vht3rGEpwcyWGgu', 4),
#  ('1AMax9MmZGUtexyvPkcEimh3eCofb8iWQ1', 4),
#  ('1Jmv4kSSgwbQYZj6DJwvKKe19qhzZn4Wak', 4),
#  ('1K8JaUCzY6QSSTHAJrK1J49ayAFeSurSoh', 4),
#  ('15Q1cK1tqceagPfgspjZSLXipoY9uvAYte', 4),
#  ('113XELoYSiYpiNbpNv7sherheRrqzXwS6c', 4),
#  ('1KG46R2b5tT8UsSKSKPJBtZrQFdaaZWVSk', 4),
#  ('1ByPUfpfn9db5f8cW9AZUUmw9BM4U6mKCM', 4),
#  ('1617LqCtoAfdhxZpXF9hJWyZ1viLg9m4jC', 4),
#  ('1CAXbXj3H8vhn549yLTEqW5YjMDwDQ4oxx', 4),
#  ('12kC6UQweWCD87xUJ2EVsvXiQdNmUKQh2Q', 4),
#  ('1NiwiSwU52VAQnbsXtTXJoxT8ZAPHRD4Az', 4),
#  ('12Mz7wJ7ZEs4qwSVsm4EW5bE52dWhK21nb', 4),
#  ('1NQudNFszKBbPPH3iyt1F9g8qSCUrMaJiH', 4),
#  ('13uT2ZnVBUEe7t9heqFinxdZu6FCUJVTTc', 4),
#  ('19oGebEcr8AaLYdZjjZ8wgdAtXXtpZVMXW', 4),
#  ('195cJF6SKMxbqhtA3uxnyF985NsPdVmbES', 4),
#  ('19QtC5DvJ1omiUrXZkznfXBLmb1Phy9LiX', 4),
#  ('14PF7dps43oLNu2vt41scQrb19S4LUw4F6', 4),
#  ('15uHaZXbas8PLgxZYXFM5a3uCExDnXmpUC', 4),
#  ('1CkqGavVrmW8STCGbcR3JXhXrSjPATyDZJ', 4),
#  ('1F9WJVb4SWfaRbjb6LMgoHahLwenA1rArF', 4),
#  ('1EkLa98xgFSdDDiBK4DhTasGQqAQPWcCNE', 4),
#  ('18kS3AacTp4GxQpkZnec1jkK9NfDQEUfai', 4),
#  ('1M7emDAZPXaWG1s9ebgnZSGxB8zNuJQyLD', 4),
#  ('1FVeZQ3q93kWVfgv2Zgt5MAw6FyADK4C2j', 4),
#  ('194g7WoCyN2bjk3TtTRoHuAGMAnEowZh34', 4),
#  ('1AsMbh2vSfhcdvR14tAzsTQFG8EEcwjykM', 4),
#  ('17sbAEKWv4wb6pdX3UiwKjmtnoCP8xa1Ct', 4),
#  ('18fwAh4365wgFMeXf7s8MZoFBWgwWgdxsU', 4),
#  ('1Kp97vge8oNA9y5b3X54Vw5hTtqU3442TE', 4),
#  ('1Nbv1L1FJRpsspg1Y2CfQ17S86TuuXdwQJ', 4),
#  ('15TRG5ne5hNk3kvu5MQHsszXpvXHL9GvUL', 4),
#  ('1FheqiWLxs5Hts4QaK51Vwean1wwh6JhP1', 4),
#  ('1Aj2V7Wb4iYCMiixtnT9un39XEbLTVNqxt', 4),
#  ('1JmAPQJDVQMks9z4VTZYvUNkex6KjtsVzN', 4),
#  ('1M5UGBKHQxWU66QkEMwkrt4qkg4dAC8uWr', 4),
#  ('1EM5V9z9Yxctdzp9bKBWR3aNW6KCRp6DEf', 4),
#  ('1KFJBiko8Xg2tZEJF19nYW2FAqzEubsGYm', 4),
#  ('12tk4kRB7EcQTomD4koybJR82VARTXK7Be', 4),
#  ('1E6ewTBdhdseC2m6Fa9xa1RR8yQvNjb9Cx', 4),
#  ('1MsqxTQZuMbiYiH6AyxPq1dykvXKNZazku', 4),
#  ('148YuB51EZvB42v1ZWnX4TTM96ei8RKXp6', 4),
#  ('15VkEHm5nzGXqEtZDmBEDVN8gqkotoXNok', 4),
#  ('1LqjVHBssEYvzNbA5mk25UZ8pE2CbAp1AP', 4),
#  ('17V9wE1BL9bQb4hwTwpUVenHHB7ehyp7R4', 4),
#  ('1DvKHVsNWFZUKPmtdZLbkTB5RZgqz3FpP3', 4),
#  ('1ArYjdHY6HPa6vK6ncgtMTy7XvacHLEDvQ', 4),
#  ('1Avke65mzkiUpJHhT42AH9hokUkT1ALiYq', 4),
#  ('1Fjksk4GurFZT5h2mrKRbao1sAYWQ3cYuy', 4),
#  ('1GfEfEvbZLF1jBotQQwJprvRZTL1iGo6KK', 4),
#  ('1MibXEkw6b1X8y3auGgfqgJcmC2jAvt7JA', 4),
#  ('13SJ4fJErFiLzRnA5WqGJ1muAaegXW3K11', 4),
#  ('14D2BEoRhKPuRm71XvavhrgK6rGWsFzZdn', 4),
#  ('1CxrDMXtAoUg853JTNqQFqN1Cv7XJAFZoB', 4),
#  ('14QGDfQ8edH4bo6e7T6P8Xgh9gkLxMU66F', 4),
#  ('1CAPJysXZvYLzKocGDFhoEDYADdd2pyMNu', 4),
#  ('1LYEaKtw3jVSjpwT2d55dYLua1QXbGkQgU', 4),
#  ('1KV2pVkXw5z66iDrhtw3Wi14KMxMNtFiJj', 4),
#  ('1BDUfTcqrwFKGEYifeMrzrrTqdRE8GF1J2', 4),
#  ('1H6gNiGAqVkXsNBMrzBMUVmKMRFXPZ4zkA', 4),
#  ('1BQUeY8Tk2BwyLArpodiKVi81yiFymrsHT', 4),
#  ('18MzU2LD5hNUWA56PGaSdhA2r6khdFveiW', 4),
#  ('14kS5r28Y8XUruUJ6hhugNtgFQhLcdYwrE', 4),
#  ('1BmhMynQPZgERsnrBRFBCdZQogJknAzj8Y', 4),
#  ('1GkK9SZgAXECd2239mBp7RjzsgJWzqXBpr', 4),
#  ('1Chx5QD9rsRKXqcicaUBf1uZx1eDXFyoDj', 4),
#  ('1PoVtRSzm8JKy31yRZHPFtgnmgmBZSmDR6', 4),
#  ('1QkkXfK9H7Nu2yfJX7kMBg9xEBPZhTyhY', 4),
#  ('12nhmY5yggQfu7dxDVZm1ot2AKDMcJqu2g', 4),
#  ('168taFu1qm7mag1h5ZLmpuYD1hu4YQNiX1', 4),
#  ('1LTZBTsSQD1RQnha8thke79CTmVmNs3Cyi', 4),
#  ('1JVbdtobEoY2gvXaPjKMgmqjV9hxJ4vEyx', 4),
#  ('14e721oPoCQtYJVszkYJuD3SG2wSzMcFJT', 4),
#  ('1BJP8eqsdUKRfem6uHBghNGDR3NuFN6Vom', 4),
#  ('15w9ozY3woVptTCpLLfWMJ9anMo8KeABJb', 4),
#  ('1L3AP1xAPr841oAFfc2gpiGA7P3aN74Uku', 4),
#  ('1A1Qw2UtX76SYLdZuQaNbVG1DZR4R4kc8K', 4),
#  ('1KkGUkVzWrivEVx3sepvA6fLZ2pYLFjX4D', 4),
#  ('1JwEmDaESF4JmZWrE9cgzUNXoKkRC1LmXq', 4),
#  ('1kT3uQnBwYGjngU1ApQNSYFG9XskAhCTC', 4),
#  ('112NfMorH66GdRgWVFUAb43nQAbw2wKgRW', 4),
#  ('1PcMxkAR4hj9Qz1fzwTuCdpbfNbWMczrDK', 4),
#  ('16NvXjFPxMTMZ9wjVjkPdGbkfYJ4dHjgSK', 4),
#  ('1PsXhixfkxNUCYcginEGSuuw3wiRZWJaw5', 4),
#  ('16PJcPk72utTezPxesUjjm2wacCoAAUXUd', 4),
#  ('1E91eQVGEVw4HQUHmKotMZ4cCAEUWBE6GQ', 4),
#  ('1EhgAM7CC5nXE1HWupg2Sn9Xe9eiQapbQH', 4),
#  ('1U7B64PC26EeesD6wP1G4rHCEPxcdNzSc', 4),
#  ('1S74RGg7tLi35vcy1ajsrUFkdNtRhEJ5k', 4),
#  ('16YWWAL9HUeecp9AUHajzQQUv2cCoeKqQm', 4),
#  ('1Jf6jLBraeGMW6ugvfLGU2E8T7V7xUp9aS', 4),
#  ('1GZgbAkZEBV9JdnngRQwUoyRqezbaRCdxw', 4),
#  ('1K8BA2GVuDX928uVFvbCJkv4ChFeEnz9DG', 4),
#  ('1DN8s3j4eJQWL6KFDnzpVXLaUAbZd6HSDY', 4),
#  ('1K6GZRDaM3YiN9h62yr7XxD3k22z7eP2JB', 4),
#  ('14RbPKyC41LBgpUUhYYv8D8pmHrupDVLSQ', 4),
#  ('1Hz6vrYZyP7S8Uuh3oGf5GzJ95cxpob78e', 4),
#  ('18kGo2tuZXJQcgvP9VDvzKEDDrKZhjiHiZ', 4),
#  ('1MGBqKYBfGwLGRjNa9zPgUN8KcMzxSSZ9J', 4),
#  ('1KkAx9hJb5aVzkAkKTMybUQdwNoJeiJWnf', 4),
#  ('1JpHHRtr3QxHtaKXSCNat2degnJrGnSWsG', 4),
#  ('17WhSsKrTrTUQ1a95QEcysRiqBtBP9MdZ', 4),
#  ('1547ixcToiynHckJwbBa4qY58W8LXVC5ne', 4),
#  ('16cKVvzyohfUmZ8gnwih3A8ftB87UVGuKz', 4),
#  ('1MvcCc4g2C2Ym75ARsH1QjJNsLayScDMpQ', 4),
#  ('131khyfH87TPC9fimmDofAdPcdv3JRKtmW', 4),
#  ('1KTvMhUSBEnS4b1J4tMeaEPb9rWFH7VGvp', 4),
#  ('1N8CzenRh3QtTi5aqqsf8YA9ipnPgy35Si', 4),
#  ('1NJdqK1722Lk17d9euvhAYuhU8s9vX3YA8', 4),
#  ('141DF9qgrWLsdosCw4bj3qdVfo8PsK3erx', 4),
#  ('1EUtDRksYnYaAbHDBCVaMbqDPuhM1CVWiL', 4),
#  ('1Kc1gD7CJj6MzfnWs4NQmBJEYUeEVEQfUA', 4),
#  ('1KAeSmuoFSFENxY4yGAFT6kAKftZRgWmYx', 4),
#  ('1KzezQkGYMuVgnSCw2y8XKSaAp9CQk5f1M', 4),
#  ('18iRuVxLPhmapVFJQCMXC4e8RnoAYp4Zod', 4),
#  ('17xzXxLoM6RXuEj59x3sEBLWyxRFSUnct6', 4),
#  ('1QL8xoY2vqexEVyUgmED1kTFedsGx97tJz', 4),
#  ('1Ak3LFn64AP7RGuj9JUMvh2mm3xEfN1p8P', 4),
#  ('1AbQ91eTaqFY95p9zny1vsMWzbDqQZuJpo', 4),
#  ('18PQRMmynYgo3f6Ag4yWppeHYyMv5av1zS', 4),
#  ('198g1hivH7VJqScHZ159QDcCnm3wFS4Ge5', 4),
#  ('1GVY7KDSzmn2gW7wUMvf9wacKXB54yne5B', 4),
#  ('16iczQ1WiThJW5LYD7Tvs4Py3MxMs1mJGr', 4),
#  ('183rwqrLFG1NN5EfRr9S3rBMC7aBSckUvM', 4),
#  ('1GuJ6omS6fHxxuooZoFokeXx8VLM3C4caJ', 4),
#  ('14i3bmbjPGj8YdMm7jfe2tnfkZWT93tRHu', 4),
#  ('1E9BWjgjAnzWeRbKAvEsJDt7hWsP3daouk', 4),
#  ('1HtRY7Rvr4ena6YjYmFv2j88YQoN3s1jmA', 4),
#  ('16XBvGUshAGsgfaRsvdsKSyBGfTEqVmSxE', 4),
#  ('12t1CTn6MFQkGpv2wo1T97iry5PShJPMhK', 4),
#  ('1AB6qpL9vDBmFJf7HyEApstU6qYKyzdXoc', 4),
#  ('1Jt8bRVcsrLj9DZ6ZUQdkeE5xR5nhmDDAo', 4),
#  ('16taUtYjUYhb7SCAKGNgtSqZMbgAMkXUmg', 4),
#  ('1VLHHDsC9iH3ALdAGHd7XfDsBAaz6yugK', 4),
#  ('1JTECKgMoqw8aAdai7UJmuczUsW7nHraDz', 4),
#  ('1JLYnUv5NKjspo3ey5YnnB4gCqexkFzEN5', 4),
#  ('19aB6bJbRsc1EWWnydd1iSxj6TowsHeTKE', 4),
#  ('1MSiXyT1CMCVxCbi1UsjnWsEUr979j6Gwn', 4),
#  ('1748XCDVJRYpxPacvEjixxeg5QtYcFRHoz', 4),
#  ('16fs3zmQvGThfADCwwTW4PCKRyY16M4Hep', 4),
#  ('14V2D7wmoeW2aYKKKUTLtgVZbqRmPRwJT3', 4),
#  ('16jGQCTPfK9QazFQk33ggKACmE5oUsF9B8', 4),
#  ('1As6YePhkfppjnSRecsQ4FovNCjgcofh9Y', 4),
#  ('17QeJnvc6ggqVwiQQXSLJ2DTNZFXpzd2as', 4),
#  ('19Dbz3YSyYk1KzUs3xFgQZZgrbfxkY2PVh', 4),
#  ('1EGHBRUhSUViTdjoZtYKDUbEgjtAdjvfL8', 4),
#  ('1Q3D1biU3tpKzbvQQTJeUi9jaTi835m1ER', 4),
#  ('1DEkEwrqLrjGMEvWPEt3ssTGZ4ocfkDDvs', 4),
#  ('1758tTe3n1ZKyY7gpN2VaprSUMNY2HHhTF', 4),
#  ('1PZCS6615yNqVD19jWi8SANw7efY6G3auG', 4),
#  ('1M6TFreUCN2vdD9AghCwxXPaNogsCVky8G', 4),
#  ('1aem1Xwc24iYWpGNwXhdDXPvKuT6jKR3s', 4),
#  ('1225JV5Zo2U7T3QU6naQx9DNYK5g5RSRF6', 4),
#  ('12ykbyJsnBYhtM1JMrZV9W7wqDFX8EjUWd', 4),
#  ('1HV1zofG6CymRQgk5fvK7tqDsrkg7gGfDi', 4),
#  ('1FxV8UiYsfvHf2sbTjugecNzivSTUWZJAa', 4),
#  ('1HxjwyMkwsh561WS3ssqCdEAQoyjTBnZTM', 4),
#  ('1MypXxchddznKpprATkPTvpojCVh5xLJmr', 4),
#  ('1N9MDaPHqxKcgWJuuGygdvBKPwZX9uneSg', 4),
#  ('12wU6KVZ4t4uWDxTM7sXyPnay7vipbsLfL', 4),
#  ('1GNQXgp9oCHLqHAozXAbVJp6kKa7sUaZR7', 4),
#  ('14bpPqEaJAsVcTHVKXotPfdN1iFsvLiHyQ', 4),
#  ('15cC1mKv2jUN2sMv2CqzJBDrczqRKoDQWf', 4),
#  ('1MLcwxQuswacD3C3swM6fjdxRmE4dr59Xm', 4),
#  ('1Kf75kNcxdP2LXgrB987AxeFBebDxKvyEL', 4),
#  ('15xq2gr5xRwtZE28XNdVZERnUeEwkXtuip', 4),
#  ('1MhSrfZy8Ezf5rbDS6zQTgRYcstPUqi5rM', 4),
#  ('19UcouRchYBb3CSVyvh8Fp5598s7JLHYyQ', 4),
#  ('158Yus7Ny3GpijgRQaSAzNkPvRnYqucaB5', 4),
#  ('1Hb655ggS6rmkhpxwvXH6rgNdcw2SgNsPm', 4),
#  ('1EEwY2xDRNwZ4rtJvLnzYae95kfdH17MKf', 4),
#  ('1MLaBBBCkXAbFmi5Vo2qongZC2AycNtZSo', 4),
#  ('152x3yVfcpvsiZvCmr3BsPjaURpfe7CLpb', 4),
#  ('14c5Kx3M1fmrdU5m1mzcWe2AWeuNQ3QK1s', 4),
#  ('1G2V7UpntqinqLMBbEBsbz5dNGRYVgY996', 4),
#  ('19cU6wFwJ9KWVUcWcuCsX3coedDihSXj98', 4),
#  ('1NkkMxP8gMDnbCVvyDMHtvkRRSPcnruZEM', 4),
#  ('1KSSWEgywnmamkjxyQXPQp5AcBVJLhWtWr', 4),
#  ('1K2UeVPjH1jcS4gKFF3vM4S99GsVRHMyp3', 4),
#  ('17VQbXgFrFnYZKLHMAJqeucHPdAcpPcxvp', 4),
#  ('1L19HXkCtFyvrLpkmdySPucBJdewvQoMu5', 4),
#  ('1HVTtAEF3M4MQ824JHoxqHT3DZFVSP4pVx', 4),
#  ('1MjyZaLUU4P3arBNxHrnXxcxshQggDpNqZ', 4),
#  ('1GU1s3fFtoNEaJL8tXPdcTtFeYvYYiLAd9', 4),
#  ('1GUHtYXAZF6eGZLP4K3a1oBfskPDCJAPL8', 4),
#  ('14SqCzy1PBqR8fAxn6DTnuDmRJwN1peHjM', 4),
#  ('1EprzaafFiRfANcmPz8BKNm8Re2avRS9Fq', 4),
#  ('1Hx9zYsi3gXyBRBcjRALRJG1RLJ83rGQ87', 4),
#  ('1K4RfxTv3aUhPde2ae78Fr5JaneYDjuQz7', 4),
#  ('1N2eYk3oxBCwNz48XCoqux5h6oQttjwh3u', 4),
#  ('1HwGTvwLQf9S62YZcXuDznXLTGEf1N5uMb', 4),
#  ('1NFyyJfw6uo2Ekjif848ViSjrBEwoyeBts', 4),
#  ('1DMC6UCPhpNfqm6ps9XmoNWJ9RREhfLAQ9', 4),
#  ('1Jq95Vf8YFqSYVrYwSFzhokXHMTcoEvMQU', 4),
#  ('19EF1FLiYEqfZ7tfVJHyCa4H6a42mBVvpy', 4),
#  ('15rNE8awQZPd5nPBguW5AXj3s35BAFf5Mx', 4),
#  ('1MvrSjJASNnYiBDd62afAj3AnAmK1NPE3g', 4),
#  ('1MaPb3gg3SAAJ2wZXgczyUcoSCs1H9ZY7G', 4),
#  ('17tE6ELBjBK7NtKSbw9hH8aevsVnfTa5AB', 4),
#  ('14LeVwVsSkhBvhZWDW7qFSLXQDoYUEzEn2', 4),
#  ('15Ut6qbVW7vWqnLhr88UqU8gmSj7DHZWBF', 4),
#  ('1JTQqoKRJELnLKHD3ZTYgnvccthR2r2DNx', 4),
#  ('14NTD7Yi8C5KMsS5jh45FjaVbMfAXTTdGY', 4),
#  ('13i2oQqfANsuagPSEVoNeTsrsdUDTi2E24', 4),
#  ('1KKQvDUXrpECdcLUJXfNZFwoQLygvkenFG', 4),
#  ('12ZJhCDJGGngJgKAsKRKEyhhv7fT3xrB4x', 4),
#  ('1PgHPG4d4HxjiF7AeoFJuPJD72RRqXAshN', 4),
#  ('1EfgeVqVs8cHraVwiuYKNms8MPriJ6cXHf', 4),
#  ('1BHjhBwEMHPsYz7Ad5btCStTRJ514qv8dG', 4),
#  ('1MUUrauKD92uP5H7BiVC7hJu5YPCBxq9sr', 4),
#  ('1D8AHWBFeTpoFRkq5B6GQWB5n5xW3Ay1bf', 4),
#  ('14reaUmGHF7cbMMWRS8bEhV5MA8gqzqVVi', 4),
#  ('1ALxk2nqzMLXTB6RfnHG252MoG61yE8tAj', 4),
#  ('17RRsBVvBrSEyKGcCVUj73gS7z4Waho4bA', 4),
#  ('1KeX3ogaUr6ndDhPjieLoStrrjuZFStM14', 4),
#  ('17VaDLuUXRDRn7vgSfSzFiVTcMvrTqqJHd', 4),
#  ('1NGiwndu8cuFbQNTZJXvee9VR1DB1mgpBu', 4),
#  ('1MginJMpT6Ycd9f3ZjrV2AKE7GtooewVjW', 4),
#  ('1KkQvxejGJWxAyqjFrbX1sWA339cu846ah', 4),
#  ('1JTSixYezQ5oW5DykLk1ZX9j7hYYB4eNiH', 4),
#  ('1MNSnng6yBCRkbE7Syu7FowrjUpomhpyff', 4),
#  ('154NKGQ5hRHgZnELQ4h49BHjCpNsSpG63S', 4),
#  ('1HTLus1e4pHBeu5KZgAafcg728ueU4GPG9', 4),
#  ('1CPCS8YJxXLMKBStbYmT7zDJHZQcs3YGGt', 4),
#  ('13LbdrqpgZ4cTNHQjSFxQun9xAZniUsKsj', 4),
#  ('1211ZUiCeSPaf9Eg3nAcs173eiKpkfDtM4', 4),
#  ('1KdRR2nkND16XPAAR1qTYHJBHz4EeHtYeu', 4),
#  ('1LWY7rY4PvUVCsVw3Y59SWdVph8YPSL5Be', 4),
#  ('1MGKAH8iGqi3i1TpzYsGu7A24GapdZ8Fxk', 4),
#  ('13ocj9kYRQi8ZHAid77rD2m4f1KxZdkNNc', 4),
#  ('1FWjfzeuynbcsZBhnGsPToK4x38vu8Rk8X', 4),
#  ('1FwQVH2WaS5JcCSwpEAXQJR7Dat3xRrsvE', 4),
#  ('13JBh9VGiq1wCqzgB2ntZGDAYPVsE94PFj', 4),
#  ('1GjaKe3EwjNbXdXn28KkKjECRFwmTiTfL6', 4),
#  ('1DgkmDQaYJy47W9ccVjwuG89R6m7EvPNph', 4),
#  ('1Ms3t1Hf54aLuAsVrmJKAsuTQwJWpiQUof', 4),
#  ('1CzNuF58f5eN6WJNfixcSeet7ijtRtXt47', 4),
#  ('18izeFdvePF1dE7azYdYYvqeZtT3kf4amy', 4),
#  ('15QVsxhDjnos9m5uxc7moddU3okXyQymPz', 4),
#  ('1JVJUMGhvQXr9JgRURSHpRMPxriV1LTDy', 4),
#  ('17R9jrjkCMSykQwZfFE2fVpC5873872WcX', 4),
#  ('1CiBm2kYxAhamK2KwJTxNnnvg2VuS3vtyH', 4),
#  ('1J5Tt31DJjAkPu6gr4j59D8cKW9HLukApF', 4),
#  ('14g9RyLnziKpv1jReSznU3sUhhbmUTGXSu', 4),
#  ('1EuYJG5uomU6k5v6CeivQDxDVmP3Y2imPA', 4),
#  ('1BaDhafZ3R4QbdXkwgc8WtKHQwnLPbxwp6', 4),
#  ('12MWCX1bpGcMmhcKQ3VCJMuCUebZX6B4sY', 4),
#  ('1HEMmCbKZU5kWTjoV97CNKweR5fHq74jVk', 4),
#  ('12TfZKBHi99T9J2dqR5nZveS5x85wT1jh5', 4),
#  ('15QjBD3JLpwrFRtjmxeBtJUpTAifmvSRM8', 4),
#  ('1FqPNaT2hu82Jjb8CZSTU6tiHpw9eLNt7W', 4),
#  ('1D7xkHbX5up6h3oFSMaKoKQenqQhKSP4Lz', 4),
#  ('17ETAeRi28m9dGkwfE3w4ut2to3BdDK9HX', 4),
#  ('17CBdHRwKuqvgFUzqqBEZno7fbnpaL7TR4', 4),
#  ('1J1DToTzhZr3ifrca4xjWj4769w4U3XHB6', 4),
#  ('1HCErE7R7Jj37u124EpM5EMDwuNNqeFuXL', 4),
#  ('1PmwxaK27djsrQMWG34cNZNPAPUTDW7k3Z', 4),
#  ('1EysPeuHNWq2iKXi5tmH54GyczyDdgKRqM', 4),
#  ('1Bib5G4F7j6ko4vJCGSgvQe7W8DS7xJDC4', 4),
#  ('1GerUqih1RpUN3QVFKRoFbhH943K3CM7Cx', 4),
#  ('165cAdd6iSrERgTSfqAkZMxDHohS1Jfakr', 4),
#  ('173tVxRRvzedUdc2AK8bQQhqd7rXiyA78F', 4),
#  ('1JiTgP9m6fBQtuN9PG1bWSbUnPGvNAqQWc', 4),
#  ('17BErAJ5B3vhbsm5imFJvZfsADiwNreKgz', 4),
#  ('17Mu5uBGqDMGa3PhwP3kz4QDDQMHHpg6T9', 4),
#  ('1G1oNHJFHoZ1yoyVwoQjFNY5pPHtBr5kux', 4),
#  ('12yAVFtKsyoJ7DckZyKbo5az4un6rYNxFS', 4),
#  ('13NHhJ9mLi1m3tu7k4QgYXHf273Mc4yj9K', 4),
#  ('16LGXEuFyVwA3fKsUSMKgJNcz3ZBabHwuS', 4),
#  ('128HAuJ44cJeWz1MDaGq2zDDSpTZpSmoRN', 4),
#  ('1PRN288xLgGgQBwvN8goJKGRv7U8bTL6Yv', 4),
#  ('147oNJPSAgFZCt69sapwxkrzpezQDyPCHb', 4),
#  ('1Lhn2Uj2fZ1NLmLu5nLhAKz4f1m4AqnEUQ', 4),
#  ('1GJwx4y9EvNjtrFVBRdYJBpuqPER5rL5Nf', 4),
#  ('1AF92JgBThoPU8QqsvCZbo9RHoPMHVTX65', 4),
#  ('15uJSw9Fdjv1ubbu8qqpWvoEC4qJJKjjSo', 4),
#  ('19e7F4T3P9KrMQWvHLEFt92Z6r4UqezxmK', 4),
#  ('1EvT8ZBeTk9iWVoB3H9ufR32RMrVP4qfqT', 4),
#  ('1Bqv5CK7YBkqoKr7hYprdimX66d1HHEReZ', 4),
#  ('1NcsaTjkH3pgWFUUBH5cE8myhTmdqiiXrb', 4),
#  ('19jXWkH4DRZt3GyfgUKhRr99SxQ1LcASyK', 4),
#  ('14LvXnGATHq3L3jbvsTFAYkdHsGsDseHGK', 4),
#  ('1J1SkSquweWU4TwWWPaLpQekHQL5LPxBHQ', 4),
#  ('161fjp5dbNEguuyYzHUqNHQrxaRYsAkvNn', 4),
#  ('16ZmqTubYoDpZWE6PDdg67HgXyQz1hNgZP', 4),
#  ('13HvLG5xUCLGUPKCm5uStBK2y3KA5pcEqu', 4),
#  ('12yfxSs2dA314dLwtr5rrARnaMAFsGKxYj', 4),
#  ('1CoiQZEpDDW8xkD5qNapdb6W8zaWyFphhM', 4),
#  ('12G64PYF33SLPtAnRRhF6ZF8WE3BkKYMwf', 4),
#  ('1MCPdMyy1YRgLzLggbuNkt3aajMyxgMcPi', 4),
#  ('113bwHKoDxpkqaFxvTnrNRrkpDaRkgTknt', 4),
#  ('15JMoEQJQKynHS5Y2Pf1TTVijPg6yu3MJZ', 4),
#  ('1LAPb4ei6bo45mP2Gd9XNwxMzrFnJrjm99', 4),
#  ('1Ex5LYsbS8wq35nQvSFwDRt6r32gTTWUX4', 4),
#  ('1MjoMV5rhmamdnhGizHyy9qBReNCjMzCoY', 4),
#  ('1CNRDjqenxZ9pd6xkShYAaRNeH9JQgyg2w', 4),
#  ('1PALgCwN336i4iiozpxcgYASuVKKS3v6cS', 4),
#  ('1EtVABJ723t6QwEnnewJAShc3DnkKC2FDY', 4),
#  ('1AnseTKr16XExPyDcsPFmAtryf6rcRZncc', 4),
#  ('16PrukC4vK65gr99mk2sSiC4EYvQ1Ws29W', 4),
#  ('1JFLVYfrNBefii57foaNfy3qkPVYVuLsv2', 4),
#  ('1KLPohnYsXTPdnLXukciMeYwqQsUQeshcy', 4),
#  ('1HaeB9VCfjkScxQUbeXEkVZSKMycR6pQPN', 4),
#  ('1HoSRcqeq8EGFN6vzwkA5xu2ckVJUDS6CV', 4),
#  ('1HWiWkxJmmBA8FGVCt4y9Qi3bARCJiNYDn', 4),
#  ('1PAdutceXupeA2FqXvSuAhs6fiQeBgWXqM', 4),
#  ('1BX22zmMEfYLgcy2Xeha1Wm6pRyEiumX9z', 4),
#  ('1J9d6DJHpaiWrhAMuPzSFqzwYy625VEsS1', 4),
#  ('1A3rGg7FFojLMVhhNzrXUB5r3SJprprMk6', 4),
#  ('1NCahM2Khiz6dPqB4yanWMkNTipVZsEoXj', 4),
#  ('1Eo8daWgnPD1T6r1HtUrbuBJkdg2SBNAAB', 4),
#  ('12Dp9AvstGg8W8cQMb4rqYLrfVMVKjtxDX', 4),
#  ('1D3GSBYp6Ga4qUqErid33vKtsBoayfmiaB', 4),
#  ('1Ly1V9t95EXbjmaYeZA9FWz4gaDdvC92eD', 4),
#  ('13eUnqVYHYy3y22ccYziz1FyKpE9QFAT8v', 4),
#  ('1AKSnLV7ABJkmuXpMxuiJ26YJryFwrurfu', 4),
#  ('1H4kZxqLFZMdtX7u5Ku7dUdJmfs7jo5Etc', 4),
#  ('16wcC7tKzaWwm1WsCV6QeJPPnaz8x2KAeE', 4),
#  ('14PDci35v2XPVT3BqxciP2CJezR9MYqs6X', 4),
#  ('12WEJKcMUtRyesPe5CBazPbYDahBe7W8hJ', 4),
#  ('1Hv3UpTWTk3QJfdQw7MpqKjUMc1G3dxiED', 4),
#  ('1LhZjW6FheYsM6aDg1Z6DjgyxcMziNFDTU', 4),
#  ('1AfDRGPghpj4rzJEQFnhhmoWCe3AQKxpXE', 4),
#  ('1AgX8c9aUieawx5KrFz8rse11wqTpx2gY4', 4),
#  ('15PpRJbm6uhPerSLA6qsZUKJJ3XQuMRsgR', 4),
#  ('136ZPSEAyAwMxkmRHK9CWkufDt64aYaid1', 4),
#  ('1HabZvJmyavd59VwREkorStegt9SRM1CDR', 4),
#  ('1FcY1c7udodUSSZMqZFWCcWxMSXDf4SQFB', 4),
#  ('1E31tdQ9rMkZ3pPCcqvTa5eBUFTm23czHY', 4),
#  ('17P3ctA8T6tCgPZtv5TjXi3Bqqw2Xro2qV', 4),
#  ('1Gw9PYvVvFnqm2mc35LKJKMP8tZ9nnfumj', 4),
#  ('13U4EiPt859wfET9cvefc2kQFRrGJ1JfZG', 4),
#  ('1P7td9RhowG9zNCfQkdDtMfYmDiRHVvZtd', 4),
#  ('1JPmLXNsvcWPtrugXhAcZrguR2PUcLkSie', 4),
#  ('1dJCUcFqvw4w8Q1ZKa6Lzvu7sqKP7m5j8', 4),
#  ('1K3LBDr36aaZw9mZ6SKjvuyxQ3zMUgK4Pu', 4),
#  ('1743DKHbdavy4W4kErAXXEDeWZjJQVHcKV', 4),
#  ('1GREq5edG7DkBTrkyDWViky5BCZYjH7TrP', 4),
#  ('1FaKKavaH77U9xrPppu8bKeQmayvzbqCpn', 4),
#  ('1B2p2noFDvpWdsEg9jbGsMykT3J2WwZ4iT', 4),
#  ('15KSdDVx45S1MtoZAHwomMTosffutG3J72', 4),
#  ('1EuzSvjgsEHij2egWjzr2U5y7tiVw6i4ch', 4),
#  ('1NRLqPNiGkHEMveSgZktps8UCKu7qwxdh7', 4),
#  ('19FW4KUMb1EyEZPuYei8ef2sXQgxN3HGz3', 4),
#  ('1BSc4oZvTrSQvmJWAy6LtXPk5WKz6pXnjF', 4),
#  ('1HvbaZ5moHsHUuxjjBR5W6C9M1gmYyFJVT', 4),
#  ('14r93DGKFxmiyvpepCCzFRiWXjeqwfHqLX', 4),
#  ('15A6dfddzdFWGsp4LJaYiyzAhuE1swAccA', 4),
#  ('1GXuKc3DiMZvqim35mSnRm7CbV9EvfcAJU', 4),
#  ('18KXdUeP735Hxawxa5wYGBm4MsQpi1xkUN', 4),
#  ('18DLQojG6bJaqkBF4VNMx1hdnUEMSuA37u', 4),
#  ('1NKjhc7S7mFR2qBrvtTPukszEJRkagn57B', 4),
#  ('1AmDcx83uEdSK2r6BHF9GDwPfEZB85DtFb', 4),
#  ('1JdqgU9GVEUyYcBeUx8dWtmkCjtC75NNv6', 4),
#  ('1EsKYbLPwMHRyuEHYM9hSHqPfQL5s2YGNS', 4),
#  ('1VwpvGpKJyKUBBg92b3ZiJi79KdBanmR3', 4),
#  ('1B7GU1UXWvdDygXisKkMDe5TdG9ouwN58E', 4),
#  ('1EqubYgcGti9CmvbTe5coSgvWtvyGSUtUs', 4),
#  ('18uDYVonwHYeMayv9yVbuVvi7BqDnk7VHN', 4),
#  ('193yQ3spJz4LbfbSBSfxaWw4eE1DVUrFpy', 4),
#  ('1Gi6CsCBUSgNTc977SEZYPtxNZbJCzGp5E', 4),
#  ('1EC2UtPRxvdrCDqiLqZFSBr3odi1EjvkfD', 4),
#  ('1P2VBaZEJh17W22CThryKzihtnAGfSyqd1', 4),
#  ('1HLcYz6XUNpMTXoLBVgJBWif45e1zWTXcn', 4),
#  ('1LngeuFL33s9bLdGQs3UzbBezXpDPjX9D9', 4),
#  ('1E77jQpEyrjMT5qy9apVhoPGkxjNAbUL3r', 4),
#  ('1N1Pbg9zCR74YsVGQ8zVBbm1JmTshkhhnJ', 4),
#  ('14GEtVasyFVaCCmXeN4P4ZYumoCGkpy2Lj', 4),
#  ('18GGZgRu232Pbi1KXWBhMkWHn5uFYot3ex', 4),
#  ('14jqskJbyTAovpJnWDXNqr1v2a7d13NLiw', 4),
#  ('1GVYU3qv6znB4piUEaBn16y8tohHxsi5Cp', 4),
#  ('13u4Ewqhad1uTcgeE3t2hFYVruaAMRocDG', 4),
#  ('1BV3iBBuDfnzogJPFgY6h63kATaQnkzP47', 4),
#  ('1J3g4xEN6kEQqEVV1JBwr6gAdTGrnqGqZE', 4),
#  ('13Sb5JpFKeuFHGnDZkr8PEWE2mnWGUJJKr', 4),
#  ('1DrNUqUDhD7PMnTCC47tvRP257ifz5yB1b', 4),
#  ('1126zBoJZay36SoSMK7PwtkHqBYk5QSMgH', 4),
#  ('1A1hNufhg64BHffHu3bS98RVUXjqZUUEYu', 4),
#  ('1BD4U4zUc32yncaxm8CCG1rmtTkr9nbb4T', 4),
#  ('16Qmu2a7ajpQD2LGkUoeHuJ67zScYq3U5F', 4),
#  ('1FSxYkyZnC25wJT8cT1VcX9cvgWPBqcvuT', 4),
#  ('1F2jRqWvxBkiFg5sgiok4RLhxVGyWrLNE5', 4),
#  ('1M28rNx5xALaSFV5PNTJbjZPkCBZaTdd33', 4),
#  ('19497dgsAadqVLg4EywhdY4iHJAmTqy62', 4),
#  ('16kugsj5sZvVqFJz9JRLAv1GTXhL2iNkBr', 4),
#  ('18wZbGai7fBsuy6BEm8TnXuMafdxArKGFt', 4),
#  ('15bD9zsVmjNuYVXUvNH8rhcd8PAdwTfeFT', 4),
#  ('1CJckCJaim6fVPrtW8YwcAg9zDJ4wni3qv', 4),
#  ('1DEZJGQi91QK9ikuiXpUCSs5xyssaTgMAT', 4),
#  ('12i1VcH4zssu5mYKKFLbB4U41XRBVuhuTt', 4),
#  ('14kzHqK6uHEPyqHkEJd2PU7ZPYZfu7um1h', 4),
#  ('18LsW9fnD3eCWfmu9Z34Axjny669Ricehn', 4),
#  ('16WpoUcARYWkPPnEk4Q5JMmBzPddPDXyCR', 4),
#  ('1HzEYz7MUYiXuEMHebSB8ZpGyKwK1HvjP4', 4),
#  ('155WRZTJMJsLk6UNjPRjmxJBBVRDpDAS1a', 4),
#  ('19iMAHpdDhomJ9pHWuA7rrEk24HM1Ls4e', 4),
#  ('16JwAQwuodXJCT7o9CqNuqL7cfdGkpzK62', 4),
#  ('1FrPUrK8DPgVuCM96NP2yEP9XiVCWTkB8j', 4),
#  ('1DrHVHNyYsUgiyYzaUUSouNG1GJPALY1xy', 4),
#  ('1569HTTqoZnw4A985mED29z6XsxZuRxoPZ', 4),
#  ('1BUrqLnces5MMrNKpvh3q1qw5X6EjChko5', 4),
#  ('18XfufxXo5NBqphCoWHrwqGmaEDzX52j6V', 4),
#  ('1DdQajvknBX6BjPbWcvYbFqnWa6f6CZom3', 4),
#  ('1JdQtd6AooiYdeJ4nJFptEybkMUMtKkn32', 4),
#  ('1B6bnE5hH2qUqgHuGJDWQxtXUt6Z9CAQKR', 4),
#  ('15YT7vp38Escq4LSH2rEpci7bTBRqRgiFU', 4),
#  ('1KXNjoiLW5cJv58DS8k5GgMUQbZqhhgcUw', 4),
#  ('16go8v2cwCgKtB7EBJjk8tzKxf5DsthTGo', 4),
#  ('1CP4JdfUuEFeU18PE9Q42e4JY1iZdXJXxu', 4),
#  ('1JJYG2MHJYVogQJY6B12k8Vv98emUXtffw', 4),
#  ('1HdskobcucjbhcK49HLzFbftz8siK5h7fm', 4),
#  ('1CFug1yVg5Sp5fyuxuSutcEiamdGBcCGJX', 4),
#  ('173CGSV4YkBm3PPspGzctYh47okigpCxRe', 4),
#  ('1ACq9NxFnn7UARKsngY6aNaqMmyeqTmndm', 4),
#  ('12mUsjSVWD2Dwsn8Y5BKgwapTp6TStr7N8', 4),
#  ('17mgry8FPNAs1zQ6mEGemc9RPctwimxgmV', 4),
#  ('1L4UaRn1LAsEecihDcRLU8uArQFrSNqRi8', 4),
#  ('181qmttYxdUw9DiqdCaVv6y7VMrdjx5Woh', 4),
#  ('12BxHygt5SGW1UPMVVQdyLa28UG9i4fhHm', 4),
#  ('1F31CK7r6DnS5F3TSH358duF8Wbqy88R5U', 4),
#  ('18qgb2cSkvHiSqDYZVFgUvkrEaTgnDFfbe', 4),
#  ('18UTdW2oWDVmbNuP3VtWeoUYsitD27w7WZ', 4),
#  ('1KU5Ga1UurM9CtzhMeTEioTqB5uQvhP3zc', 4),
#  ('1Gy7ifp8p9wSXRtFzMVTJhqMR36oQg2U1j', 4),
#  ('1NVqGFyNTizNsPcXjafgprGrNkxBsmdUhR', 4),
#  ('1M9Jz1QXZEsfzCZgXEPLsg6og8v3NrgmqR', 4),
#  ('1KaPbLooXsJmJ1nbj2cu3R4YR7ZyvCx6zx', 4),
#  ('18ZPua3sQZV26EPVXYy9DcB9TpVRJ6S98k', 4),
#  ('1EQVodPZ7YU7HbS9CjoZpQ8Jt886zUGR2f', 4),
#  ('115jByGXoFr7hsF1tjvKyiiCHFL9tDPPdY', 4),
#  ('1E9S8oJDa6UushUKp3WJWpzDdJ1g9Qauya', 4),
#  ('13QDgbLKh1prNurstCYF5Xj8nvAN7mx8mm', 4),
#  ('1iaaWFuq3UioSEshU4TqPqNRw6bqpNwbY', 4),
#  ('1Hcf2FR9mzUmxdrVcsx58vFwVgsPsWDd7j', 4),
#  ('1F82nkMasEpPhkeRqBhgv7krf9d4Xnrm8R', 4),
#  ('1FgqMfU5PP4DS899FtAiKYrEekZq9aPn2T', 4),
#  ('1JFC992FwGrtzT5bWeMe92R9doxcPzUunJ', 4),
#  ('1L4UeaMaWBLZztieXZ1WcE5wrr4VLtH2hT', 4),
#  ('1AJsdq3e22JXHsFAZZbFhotid6gFvmU2FX', 4),
#  ('1B3g9BPkZi67RRpVLiHDFZ2RJSesdhQptt', 4),
#  ('13TVscTyZ6QRu2BqqfbE4Yk6RHSK28WhwD', 4),
#  ('132CYwwSaEz3F5Duzy2mBKH2vqfwAyzJ46', 4),
#  ('1MCqk1grnQL8dUbaVcn92ubAgZj24DDqXU', 4),
#  ('15DKWuMMTq2CX4LkwQjxJSa1oB5jyAG2ro', 4),
#  ('1LGjz9S1p17cH6aC1gjsBN998AXo4e8TTS', 4),
#  ('16uad1bxGJ47zVGRcj1A2WcuCfBmm8Q6UX', 4),
#  ('185uq2SNKNjD2bhK2z9YurNdEJwr9kF81w', 4),
#  ('1Ao6ZAWRTr1o8F5RqEc6DynSDBbyTR6CUo', 4),
#  ('14dq5ft7dLNG2YegLKh3NJn2dYNbHe3oYs', 4),
#  ('1DpniibzsnKxHmAsTyy2H8eKBxHdamUwdw', 4),
#  ('1Q4YqKfUBh2kxhqUDcmPqFhh2veh6f3byK', 4),
#  ('15TPHx3wimZqpXK9oBZTPauG2Gg7HZSdCu', 4),
#  ('1MAKxSsS5Xd9tAjgEqx3eB6nNmoLFqhvBx', 4),
#  ('16qoUBkVyLsjeYmnwbwhRVmxrqeCSVCMaT', 4),
#  ('1BPRXmNarfMRV8nNADHmKW8svSmtKaFJYG', 4),
#  ('1Jo2miMwMxREULf494c8Qf6u49TPxRNoMr', 4),
#  ('1Nsf9RgpcnHTjZnB3uEnCkCxFmkPFPB2d5', 4),
#  ('1N4aDvSbXdKwGSAddgCSqR6GF5S5RmRGUE', 4),
#  ('12kCcc8aRJk928dpDYcphweP3M5sR2bWjn', 4),
#  ('1LeVMJPdiTXXPwZBKmvUjUhdDXfisLq5fW', 4),
#  ('16c9XzvUTHqZML8ACLXRYS9ZPjhP2v27xb', 4),
#  ('1Gk9M3wrjfZX7u4NGivU1M3iPapubfi4h7', 4),
#  ('16rzTJ9nREVx1c7BwjyJASX26TaFcZs3BM', 4),
#  ('17iuU65svi448KDsqcgSJZqiznD2dCifX8', 4),
#  ('13LhkjNBnFjLtEhSzxA4J6SRzjkYWF5ewF', 4),
#  ('14ZbAY3DD4bpFkaPNrM3Ccp1vBhDMgNnoM', 4),
#  ('13y6kUoxittJu3QazqDbYAXrL6wCKgwj3q', 4),
#  ('12ihEHYkLJ3ix7MNBRoFpA4z2m2JfGmP6B', 4),
#  ('1EvnMskyf9W8ztGxwE1HTB6WBiibupnjyc', 4),
#  ('13AkEvS7ZZBJtdHpunfZwqLpXKuujnMfG7', 4),
#  ('1GHdqyr535E5huJndHdpsfZXfEfEAKTv3d', 4),
#  ('1QBRpni6jFAGkgumgrZuU6MEwbves7v5Gf', 4),
#  ('1Co3X9S2R6qWXyCaERow7mzJJkYUZ5Fioa', 4),
#  ('18VVarGxYzhzfuAeC2kXFSVxhKFdhm7pfw', 4),
#  ('1Gd5yabAc4jqvPpthYGtB7Sgiu2gPwsz7f', 4),
#  ('1AH3TyCq9f1r1H2TQtnUL1LuXy6GyENvCF', 4),
#  ('18arFcY7Bexp9zawHjgVdddd1rCv3SLHzP', 4),
#  ('1NQENGHQFMhc47WCjJKbzZmD5cHzYq2Wqt', 4),
#  ('1Kb3SF7o39t4TZd3dJbAT6SxWeozD9rnPb', 4),
#  ('1772GpamebvcboZ3EDmNC4vEaMEcZ7xEun', 4),
#  ('1DqnmP2PyiKgv76sAAYmoTPmqD9vSRscLP', 4),
#  ('1Eh3GQXqRCqMkmZFPGZbpLk932xrfXcCTa', 4),
#  ('1MKffyunVCKsxdMzZcCEpqfygQJzwj66kb', 4),
#  ('195tuswcstQ4NbzXEqE7VcNWrMDwzWSgSt', 4),
#  ('12yrzBq8FuwAiUjX67tEuq1oqdoeWjUsPb', 4),
#  ('12UtAmecRyxr1woHhUsXoWKdPD7jKtcLQD', 4),
#  ('14ufGXPK5HRT8iF8ytEJe1GZ6ooKHzjibP', 4),
#  ('1KT6ZPLR8GGa7rWBHxxggZpdAbRHamyT4C', 4),
#  ('1ND6ZhPf7DvebJQU8k6Tw6ac4eiv2GQ4bY', 4),
#  ('111Y3BkUGLSWQjHCb2Mg8oMNiwc1jxMwe', 4),
#  ('1KFzKoZHKznbKgN6A84jx267o1u3SaHPLw', 4),
#  ('1DizyYAkzeN7rirrtq7HYWhpxhXQ5JRQmy', 4),
#  ('131e99eDXAb2pLHFe6bGYTDcxwdCFnMRZL', 4),
#  ('1KkhZeqB1C6ni1AjrE7UKR9w7M9kvhWqLS', 4),
#  ('1KF213cowxMGUNvY8fcBT9U3dkXDTfLaJd', 4),
#  ('1PiYr7naVVtHhhLaBPcmTbaqtaCXYFeWDQ', 4),
#  ('1LGnbWTZDqNtALgwJM8YPG37WkRhVUz21u', 4),
#  ('1LCgxE1aDsvVpMY1yCg8ZRN4BuSZuDc93g', 4),
#  ('1KSJk5ptxxy8ujLxnpMNKADJVv21DZYgUj', 4),
#  ('1ApRfGs9FyBNXgecSxZLDvm4ohzGMBq5or', 4),
#  ('1MmsUAqJDKpLJ5HaAtDofjzFurSXdNsDzS', 4),
#  ('16NnSL9GTc5uGAHeqm4piAizRLgfrNosb2', 4),
#  ('1HDV8inicztMzzRWqSxGfgTKVtrkscsinB', 4),
#  ('1F4wGZNvPtcHh3D6nDaSLGLEueQ1cXfb2N', 4),
#  ('1MSNZb2XT7vHNuX7jvdmyNdju2nhMMJ4zU', 4),
#  ('1HZ2nSAKNmmbFcEcoVGCKAChbAjzFhP64A', 4),
#  ('1K7Sh28uDqhbnXgGKYKPpuUjSBmix1TYV8', 4),
#  ('133CVAK44DRSxucAoLYX3CRvQTkuFSLEmh', 4),
#  ('1E2xxHa8rDG73m7FKhDeYVCaY2iyv8psYU', 4),
#  ('1PGD8YgBL8PSJSV4pJaV9yDd6jyvGJEPHh', 4),
#  ('1GTvCozcaZcG1vkzyUogbt3yPKv6yvSe4x', 4),
#  ('1A48JTdSNZSUjarhEocCewzdyskXhtHPAb', 4),
#  ('16Cqp6YusNLS1Trt2APf1D1oNiC7znUv5h', 4),
#  ('19MMPBsd6MhzsPREHLb4MW9mq6DeufLTP8', 4),
#  ('1dTohSs55hMXJUf1wejuJYHFhXaSXVTZb', 4),
#  ('1LeFPo7PMg33yuaXFM7DhDGrpG1jShcchv', 4),
#  ('1KA7fMwxkUNZkaZmy3RZjLfuqTLvSahwHG', 4),
#  ('1LAsK4oA5Q36HEARoUrtrU8VPLmwgbFuzq', 4),
#  ('16sPTLyqQ2n7FnhVCXvdwhyeBzmoLUULg8', 4),
#  ('12VDkntdnPeKetdxo16836BZxDZihonQ8N', 4),
#  ('1G38npYdkX3vbbjyvmxrS9zm2stnFT5u7J', 4),
#  ('14niauS5LsD4B9N2yTECC96BXvjgr9vb8v', 4),
#  ('1QLbki3LShDUXYcqcDfMBTw17wR1uWEZGK', 4),
#  ('1N1493PE5c4NCCn9joJ5BwDYdWRiboW2zd', 4),
#  ('18UEaffGNHmkCgHqhtLPfLPjxbTWPXYCWd', 4),
#  ('1Ma63r2qUCSYdd8hp6bSyhVpGmgknAvNba', 4),
#  ('1AV7hnUpnKpWVhmCzXCu7iGhmDuTx8zQk7', 4),
#  ('1KcMRwuwJaJK9LdYxKqbXMc2Ehv2PYjEHz', 4),
#  ('1AY1uetUT8jeeGmUDyRsfXDqcmFTZtDym6', 4),
#  ('1PidSnRhdGBcQ1J4yQ6bLBEdF3TQCP6TjD', 4),
#  ('16qgwxK96PtFvKyXhajeoZjrQbqrguXgvQ', 4),
#  ('1CgwvqcPjvxFTVPPL92jiShWpYiCBBreE5', 4),
#  ('18GuUVG4HbYYeaie3ssbo98ofgM6b7D7XX', 4),
#  ('1P1WFWYAjEYx4938qo9SKt6S8kSn7HoLh1', 4),
#  ('1DorLH54qAQrKqMXG6RpqA9uZonksQNCaa', 4),
#  ('1631QHufNgaWdCBeYsK56T6wyNrMVKSc6g', 4),
#  ('1GLXeatn7LE2pL2JF4HobQ4RYYnecNGkuw', 4),
#  ('1NrHddB9t2EeYd2GSd874fDr1zYVSPEBzB', 4),
#  ('1Ef4RCDTPnGAiA4LBPMWWBwXDFCYtKw6T3', 4),
#  ('17QS6fSgZtGz4bQCL9wXkMn24frMxU8JJf', 4),
#  ('1AkpyUxJDbSH1G7iov34zg4NZdWuRbF5EZ', 4),
#  ('1DrKJHV9FBskdQuxVNdEGnMCe6HBwMSGyu', 4),
#  ('1Pe5UVXsKDocug3rXpgeCH1mZRQY7uFjht', 4),
#  ('1LdqC8fHSXn4Wbnv6s1uUN6ebEvssnpS1v', 4),
#  ('1GxH4KKfgcmhpidP5YsU3qrrbCsdTtSoc7', 4),
#  ('1D6jayvN6dgFjC9mcsExezi7edMKbFXkWN', 4),
#  ('16XzSqykfYo4JSeijfih4UGPF9D3492w3k', 4),
#  ('16iRbSf3jxQ9yNkWpjTS8qXERd266932GS', 4),
#  ('1MkhwLeoEJgk5NPxVArMY5apiUyCYwwCsJ', 4),
#  ('1Q4bJ5mCpvrkSZnrSrzXbv1C5g7ZaDueHM', 4),
#  ('1Hb2cZ7Wn6hNJtFF9FeLoDrcAfbz6vsSAF', 4),
#  ('15mrT2FBLsVaoR1FFTmFi8GEjmCdnMH9zh', 4),
#  ('1CtHJX8Rz4oaBqxDYS1VaTg7VWdKj12fx', 4),
#  ('174RNJpatZC5JSnTwaqtw8baD9N63NarAk', 4),
#  ('1NnzZXio18Sw85EarGftJG9CXyzaRkJ8ja', 4),
#  ('196sqpr5yjkVBqbLnB3x5mD8pbj24JAJyB', 4),
#  ('13HcDEuGopnBpoSavxvciJVs92oDEmpUJz', 4),
#  ('13p446na8YEUJKEYRe1AwRrrGQdHB1rh2i', 4),
#  ('1HPcZrgh2aGwdni8eSdqfcY2krZrKLZ2Z', 4),
#  ('1JCAVoJaJRviiW9FauqPvQGXjkVXviizTu', 4),
#  ('19bjfgm2LL9peyGzbTcsGfMWderUAufAVp', 4),
#  ('1PUxJ4XNJPjxwixtpzn5mqncGsqy2VBnUg', 4),
#  ('1DCy5SMatnxEHUVR5Qzhbd6b6yzB1e2zpR', 4),
#  ('1FQh5fDWoF5aZ9jPJeRnVyknErRH4R1hJf', 4),
#  ('13ujuTd5pBHBo3HxRcsEVkZNfFdwkRFiou', 4),
#  ('12sLDWUdXNJDoDVvQpywruzivYhQJyFfjc', 4),
#  ('1AJBtCxcfSEi2yUs6dnNdRQYBDxUL9aQvq', 4),
#  ('1KVzpwLQMgthCcFezWbwuYtH5Mu1BwQRDG', 4),
#  ('16PoziicHdzWWKmqpniLouhkVVW9An3EoB', 4),
#  ('1H6irVkFSjhbbuLbCbF3MKJkvcZuZvrVbz', 4),
#  ('12bRR3GYLBz53S46NDmc41FEeqNLAyzksv', 4),
#  ('1Km7qwzANMj6LiVS4wa7bJGBSVsZq2maQH', 4),
#  ('1FstBqLrNZF8cU1Xb2p7gkJGtt9NrUetGT', 4),
#  ('1KiqvG7yHRNUqRhrUGXQfR1V7ULfFaucmZ', 4),
#  ('152GThXn1mzLmv6KLzeMQyYZiXk3EG94Te', 4),
#  ('1AS6dj3BLmBvYCpB2uSvRxm1UfoiX2Pspg', 4),
#  ('1FJuRqaxskiMwaYpCbKpkM8YHXeQqM75eG', 4),
#  ('13cszN8YR33MKA44DjvrUCL2uxZuGcMPNQ', 4),
#  ('1HsSj1n1skUAxVmZ1HZpVRgxDJcFv87LdZ', 4),
#  ('1DTHPY7chXNkTNrkjmWFenMjiqgt7oporM', 4),
#  ('1MoJ1J33xzGveUYN7SBYaijySrdD4a4hxx', 4),
#  ('1MJgUiM95iUiHyJDdzF5hRPk4RNQoiExeb', 4),
#  ('191RFhCBxV8qbvdZHKG3mcUBKf6RAHrynm', 4),
#  ('1PGpMZSmMiWRFUTAvxhKBjdHsufFtDb99F', 4),
#  ('1Lomt64xSTy7WDRq7N9s6HDaMS2Lgx2Zay', 4),
#  ('17kY7GEzzfvZjnHFGH3XRGiewxYaUNWWvW', 4),
#  ('14det34Tkdd4ujdWiiWGpsi83rF77fF514', 4),
#  ('1NkgMTqJ86gEeXUyvC69WdLrrKk7Tupqyg', 4),
#  ('1KMBr1bPpCe4p47aEgFMWsnT13USd5Cr1F', 4),
#  ('1GUjYmRgaMupxTjBSbtN12QUcR7cRB9uN6', 4),
#  ('18Hb7SuyFavKim4b1QggXdhGQRhnZsm2Ab', 4),
#  ('1EXWjsCvY9UKSdEr4jMNgPpX52tSMsJ74A', 4),
#  ('1HSXXuvHzFDnRtWvkcrWsfz2rfPZ9FD1qT', 4),
#  ('1FsUnYgSXYB334n4zL3c5hAXoys9VDsFwF', 4),
#  ('1PxzFeEz5FtEYuwHGePjXqEcgzJ8n9PVeY', 4),
#  ('16YEYYDs2W4JZcqBExGqeQV2vdVJ2R9SLY', 4),
#  ('16p5zAtUdsEc1NhHYjQK5YkxzYXhfgZbE3', 4),
#  ('1FifXear4GsfvAuVyE6VSzFosySzFbVrzH', 4),
#  ('15mFUyUqSdAYAsFNtbMU3GbYcWUzwjaw7M', 4),
#  ('1MSP6j3TbYYqd8QRtqWvxMNevFTgHWQZY9', 4),
#  ('126pTCXj3yaAb6LLEu25mEz5oi1hQh9qqC', 4),
#  ('19xHvQv4cB8Lx52yewLiKBC54SRXxyUGVR', 4),
#  ('12ueMQY4GNRZtgHniaLFquJw7A1TDmdZ3p', 4),
#  ('132QjfWTcmZpGrVH75sZMmz1kBuCz8w1vS', 4),
#  ('18CKp2XqMiRKVD9nSXD3tQXXMp8gS4Nzsk', 4),
#  ('1AXw4pGf3dyo7CZerKXCi5tTg6u8cvLUui', 4),
#  ('1QJtb2wm4WKnmRGXX6n2nbuw4cX4BPPfFV', 4),
#  ('1LGr19jrxRD4rhcndKGfhRfAYBUaJqguyv', 4),
#  ('1AYuc1VgFr9jXw6tnhTpyKw1a856J1H8tB', 4),
#  ('132fDtynroBy4BaQ39g9KaWkEuDmZU11og', 4),
#  ('1D5f2EPa7wJXD45pbpTUkTE7ZFRYLbrUqf', 4),
#  ('19gYUswRGS9pfWq5N5WtsWXRWrdCh36aHz', 4),
#  ('1WEVSrtVTgYgFD8UB1n1aAj4VzdEZ6G5A', 4),
#  ('1PZ6a9LRhWvPP7dvHJioC2tMwMzbDxwuXF', 4),
#  ('1LwpxfwStsgQ7tLMY9hefy8ioxxy6syjEC', 4),
#  ('1CZqn58Kv2rKYFE8JhyXAuFVkdo7D25RSK', 4),
#  ('1QH6Ak8CtXNz2kwGKfcKiMzGaePsit1JZ2', 4),
#  ('1JTmFR43jLaxd9vMy1m9BnoQcKzRKtodRm', 4),
#  ('1E7XGSDbXpnCDNdizUiHydtpLD65RHA5mQ', 4),
#  ('1EZBi48NGLL5YzVziG9hNDKcqiqnTdq8zC', 4),
#  ('158etwUkCE8BiKmHALCLFWmCZQdtCpcJFg', 4),
#  ('144q5wdRMigFx1xaoyutGunfEaUX23cFdb', 4),
#  ('1JBUmU1u9tHXHHT6pWmQDsE7LZERzQaNP', 4),
#  ('147W6D5GfHegeEsghmE9Vur4sUFoJBTmmT', 4),
#  ('1Aryk2CrS5tJqs7vdUDhTUR53erPfQHSky', 4),
#  ('1JPE6ogYsvZrLAF9kt3CekdUgPfjst5QFF', 4),
#  ('1F5TkJMBjMCm3fe7W6NMQFb7nXeYUZnj6H', 4),
#  ('16RUVmdhmnqmo8Umm3Prdmqx8yBG9tgcMY', 4),
#  ('18UFUsLB8iYDpaELCU6rsYcQQFzZLVZ4NH', 4),
#  ('1LNVbDeK7EpAFUmYoawJtFuc9QBXo14ZHy', 4),
#  ('18cDb6PZ1au4hX181GcuJ8E6Kw17QmRzMx', 4),
#  ('1MGz7kMTpboosHq6FbDLGA3CEaXg59NfMn', 4),
#  ('1P4cpCX8Pgz1qii8ZnK29HgCzfHeckXzRQ', 4),
#  ('1FLPwCohC5qtJ9rWgECLe7HLHELSwQzEkF', 4),
#  ('19JF7gqbsxrgHTcTVMA3mopRxgSk1A8SCJ', 4),
#  ('14P69oUioPm86zyQ3TRD6HhSabXDXsbJFk', 4),
#  ('1NoodPR4ijvDDWDtVm52YSb4b3EiTXsr8M', 4),
#  ('1DDrw6yoMjpWM8xu7c8NbD68LQZAES8gaE', 4),
#  ('1AwxWHc1wSBMunnCeRBeTVYYXQTr41Hh4k', 4),
#  ('13oWjWPpQQRzN31veAPe8Z11eU7HNZUUn6', 4),
#  ('1D9WSXPwsozd2unbVKJxRnoQmpDWZdttxZ', 4),
#  ('1JFJXtpeHJVsxCByfSA51XRVqiyhBXZs4X', 4),
#  ('1GFcqjWQtPQ8QJCmDEZYC4dpE7YH2mHT6M', 4),
#  ('1Q2wTc2o3NNJJqzwWzPXm69u6dDBLYqguP', 4),
#  ('1LTcMACwoWTi4D8nFqSh4C227f6nUtDz1m', 4),
#  ('1LuLkHf1bTpUV59U8ZPG78bSKnNTAyNqir', 4),
#  ('16uRymyH2rdm2Ka8r3CoXQEPVMPJrmKW5F', 4),
#  ('1BMNUyzJgudWBtp12cEutV1zA7w6TaXn5J', 4),
#  ('1qzcNBpn5RaCutRoWj6FrUkkXwWHLphfW', 4),
#  ('1AR5wdA7bnXsg1GwYRQHVvtpf7xeqwMWhg', 4),
#  ('1PCHx2VqWe5KH9rk5RcJ4Qbz3i7oCnhCZU', 4),
#  ('1PRsLMDxcxHEWv43HFuJjVRFiYSk41y8Vt', 4),
#  ('1QLVhcks4TyVFLpAcsCyCc5keTpFSgFZ5P', 4),
#  ('1AV3a51MB4AXWWXHRXZwagcRgM28FKfmS9', 4),
#  ('15Z7As694BHDiJJDh12eBH2yD8QmzGz2Cr', 4),
#  ('16TFG2ckywdHDjFAzSNP2fK3yPV1P4jeoV', 4),
#  ('1H85muZGRHfKzcgCQXsTgG2rSka59z54nU', 4),
#  ('1Jo2tcYopWkm5ugBo6d2cF6qnmuaya1dvN', 4),
#  ('14ttM3HXaMLsUYDjPpQn2LwJupxBfZgCpt', 4),
#  ('12WEk2jkzGUVcvNjSh7AKwe7hrr3cXWvBB', 4),
#  ('1MtwExjXe3pWK59sts6kwNuJAfjUcLkTC9', 4),
#  ('14e6MRYa8t8QWvnZKeTsMeP76YU7w8Unqf', 4),
#  ('1DGY76b5Npx9RzyG1uurNthK35h18Vbowh', 4),
#  ('1C9kfh5GhzUaKQeggRNtTRVTCh4MPTmZQD', 4),
#  ('18Ws5BkegfFuzdNXDE9otHvFjnea4jy9do', 4),
#  ('19RyafURMT2XATfXoR1UH3f2VywkD9A8E5', 4),
#  ('12A1HW7ZD6dRVxPvp5JV2VFwacaDqYsakQ', 4),
#  ('18wtHVVHziyWMAoGX9NCbnaPd9k6bcBZaE', 4),
#  ('1PyeiQRSYzEibwCcdQpveyLqQShxC8cP4D', 4),
#  ('14Adn6YYaoSQwmzWxZgA9cC8eRH66yLVSn', 4),
#  ('12J8d5VfrvwRnXQuPgRoAoYnzazb1ECwqh', 4),
#  ('1PioWRPydVtTjsPdu5J8LuCcuWXRkmWi8c', 4),
#  ('14NhsibioafmXn2aH5oDfLBDPEnvngdqQH', 4),
#  ('19qUBWpe4kj2SPFL5jyq5Jaco2PwgWE776', 4),
#  ('19MyqT1gKrvxUJvNzrdo4NK5RGXRcCfBCK', 4),
#  ('1J4J9dhNzj4yFXQTx8cqM5neZocVnUDtG8', 4),
#  ('1Cr486zV52C4vnzfnySUEHh1kajRsz2Ntv', 4),
#  ('1BEqMaTiyGpo8Nq5iWUURbvhs6F5mhn6iy', 4),
#  ('1KAgXXmWxf9Q1MuXPQj1EJ6aQ2EiXo7a5j', 4),
#  ('1EiK6rLZiv1yqNQbDmS4RewPFcihZDDA6f', 4),
#  ('16zrqiMYh2DJPD6k9WR85fzeHL3CDwdsbE', 4),
#  ('14ASEvcm2HJH8NfGzni54T3qPhSU4bdXgx', 4),
#  ('14gsyrXmt4g3XYFHSm1aBJxfXJetKhHcVH', 4),
#  ('1MYY1sN7BkCfNCWu6TTNsj3vCM9ziYXPCB', 4),
#  ('1B4tL1my5cs6unfmzY5fUn5YAPFqAEDMGj', 4),
#  ('1PsgVYBADcSWzoSYCJAksjxNbXqU2hzDjG', 4),
#  ('17tyNdVqBoEo3EcbYKKESRsWzuGTRws9UA', 4),
#  ('13DpG4vPsr7FoLFHjj2Q3M8jwhkWFPpSJi', 4),
#  ('193YU29u9SLRoso8nszV3RddYbYEx447SN', 4),
#  ('1MzLvKPK5Hxd82xKBLUDdDuahNoRiWXPjU', 4),
#  ('1E789LkK8YUTnMmaMAm3gxLbRtuPj98SGR', 4),
#  ('19VTDCoczq5JdMo7LvtGvhEfBf4YQD44Cn', 4),
#  ('1CFukpmj9eNmrkN7G8bFJkXrA4GREoCrns', 4),
#  ('1DWpHJjPc5owQFSokbVaSkpGBqSQaLTwji', 4),
#  ('1BWRw8C7s1Mpc32tNmy7E3Zqtx31iVcXUg', 4),
#  ('16HgAzzugtpfoiUtjQ8W5n8NyUfBiSmgPC', 4),
#  ('18mXLRB95SMktST11y8WDSjHwWQ5nK6UGQ', 4),
#  ('1KbeTyTbPUU198tjnWenDnPUXJ6hhxF8wW', 4),
#  ('13z4svLULwHYDVpoS4C9uiGfnpZbZSLaRg', 4),
#  ('17KsyXB8JCY763eZkrjwT3MQCxf9WjTn8z', 4),
#  ('1FixsQ3Ms6vh1ySofJAD4WXfHpE9uH4ym9', 4),
#  ('1CRrJLEf3ytssh1ZoDFptJCdRibWWCJS4X', 4),
#  ('1H5ebVTPnftRpJpiZL4mJhd1HtpQhF9TL9', 4),
#  ('1BnuaVhVQwCrKF2UvgLZuHzubzWe3qLLAo', 4),
#  ('1JDApXXA4UvKQkEoPE75drDwwSjRFUNPXf', 4),
#  ('188nxdMfws9uuC4G5uopWjmNMnuWAMwYGs', 4),
#  ('17GUMSCWKg6tAab2dbXwmvjxip79yhVHGr', 4),
#  ('16RPwsLNRuikqcENFh6NQTQGZ5jvsd3Ffb', 4),
#  ('1CShdmjaYVa7K1SjaLZN43xWa9Ct4UTiJw', 4),
#  ('1Bxz63bkc4aUfZgiCDT1Sa8rD91vMy7oYJ', 4),
#  ('1DwxuGikScM3X6KFqU8vwvA8hq6GcCHyMW', 4),
#  ('1AnRxLKFMaMvnE4GwyzJLoTifRFgdhgEPZ', 4),
#  ('1JEmPfGEGbqvYmmbitLfpuCCFwLfDFkL4', 4),
#  ('196mDJRkvoYZJ3pPXymDUzvBejFxVsaSsj', 4)]

# %%
addr_to_component["1PQBBWY435CTSnir4wrfD8HXZ4E92v9Xd6"], \
addr_to_component["1AueTrCc9oK7ovbtfYeVSJe4UQEaxcRMFy"]
# Out:
# (4, 4)

# %%
tx_with_users = pd.merge(
    left=addr_tx_df,
    right=addr_to_user_df,
    left_on="input_address",
    right_on="addrId",
    how="left"
)
tx_with_users.drop("input_address", axis=1, inplace=True)
tx_with_users.drop("addrId", axis=1, inplace=True)

tx_with_users = tx_with_users.drop_duplicates()
tx_with_users.to_csv("../dataset/custom/UserTx.csv", index=False)

# %%
tx_addr_df = pd.read_csv("../dataset/Elliptic++ Dataset/TxAddr_edgelist.csv")
tx_with_users = pd.merge(
    left=tx_addr_df,
    right=addr_to_user_df,
    left_on="output_address",
    right_on="addrId",
    how="left"
)
tx_with_users.drop("output_address", axis=1, inplace=True)
tx_with_users.drop("addrId", axis=1, inplace=True)
tx_with_users

# tx_with_users = tx_with_users.drop_duplicates()
tx_with_users.to_csv("../dataset/custom/TxUser.csv", index=False)

# %%
addr_addr_df = pd.read_csv("../dataset/Elliptic++ Dataset/AddrAddr_edgelist.csv")
addr_with_users = pd.merge(
    left=addr_addr_df,
    right=addr_to_user_df,
    left_on="input_address",
    right_on="addrId",
    how="left"
)
addr_with_users.drop("input_address", axis=1, inplace=True)
addr_with_users.drop("addrId", axis=1, inplace=True)
addr_with_users["inputUserId"] = addr_with_users["userId"]
addr_with_users.drop("userId", axis=1, inplace=True)

addr_with_users = pd.merge(
    left=addr_with_users,
    right=addr_to_user_df,
    left_on="output_address",
    right_on="addrId",
    how="left"
)
addr_with_users.drop("output_address", axis=1, inplace=True)
addr_with_users.drop("addrId", axis=1, inplace=True)
addr_with_users["outputUserId"] = addr_with_users["userId"]
addr_with_users.drop("userId", axis=1, inplace=True)

addr_with_users

addr_with_users = addr_with_users.drop_duplicates()
addr_with_users.to_csv("../dataset/custom/UserUser.csv", index=False)

# %% [markdown]
# # Проверка классов легальных-нелегальных по пользователям

# %%
addr_to_user = pd.read_csv("../dataset/custom/AddrUser.csv")
addr_to_class = pd.read_csv("../dataset/Elliptic++ Dataset/wallets_classes.csv")
addr_to_tx = pd.read_csv("../dataset/Elliptic++ Dataset/AddrTx_edgelist.csv")
tx_to_addr = pd.read_csv("../dataset/Elliptic++ Dataset/TxAddr_edgelist.csv")

addr_to_class.head()
# Out:
#                               address  class
# 0   111112TykSw72ztDN2WJger4cynzWYC5w      2
# 1   1111DAYXhoxZx2tsRnzimfozo783x1yC2      3
# 2    1111VHuXEzHaRCgXbVwojtaP7Co3QABb      2
# 3  111218KKkh1JJFRHbwM16AwCiVCc4m7he1      3
# 4   1115LWW3xsD9jT9VRY7viCN9S34RVAAuA      2

# %%
users_with_classes = pd.merge(
    left=addr_to_user,
    right=addr_to_class,
    left_on="addrId",
    right_on="address",
    how="left"
)
users_with_classes.drop("address", axis=1, inplace=True)
users_with_classes.drop("addrId", axis=1, inplace=True)

users_with_classes
# Out:
#         userId  class
# 0            1      3
# 1            2      3
# 2            3      3
# 3            4      2
# 4            4      3
# ...        ...    ...
# 822937  569509      3
# 822938  569510      3
# 822939  569511      2
# 822940  569512      3
# 822941  569513      3
#
# [822942 rows x 2 columns]

# %%
user_id_to_classes_cnt = users_with_classes.groupby("userId")["class"].nunique().reset_index()
user_id_to_classes_cnt[user_id_to_classes_cnt["class"] == 3]
# Out:
#         userId  class
# 3            4      3
# 31          32      3
# 35          36      3
# 110        111      3
# 127        128      3
# ...        ...    ...
# 93412    93413      3
# 183347  183348      3
# 205323  205324      3
# 227113  227114      3
# 248222  248223      3
#
# [62 rows x 2 columns]

# %%
wallets = addr_to_user[addr_to_user["userId"] == 518392]["addrId"]
wallets
# Out:
# 771673    17Lr3WNwJPJN5es7pP5RnftNGskcPP24L8
# Name: addrId, dtype: object

# %%
addr_to_class[addr_to_class["address"].isin(wallets)]
# Out:
#                                    address  class
# 166532  17Lr3WNwJPJN5es7pP5RnftNGskcPP24L8      3

# %%
addr_to_tx[addr_to_tx["input_address"].isin(wallets)]
# Out:
#                              input_address     txId
# 243417  17Lr3WNwJPJN5es7pP5RnftNGskcPP24L8  5559864

# %%
wallets = addr_to_user[addr_to_user["userId"] == 48539]["addrId"]
addr_to_class[addr_to_class["address"].isin(wallets)]
# Out:
#                                    address  class
# 218700  192WpD5RLTWARzWT9wuMoeQ5JABHXWnwZw      2

# %%
addr_to_tx[addr_to_tx["input_address"].isin(wallets)]
# Out:
# Empty DataFrame
# Columns: [input_address, txId]
# Index: []

# %%
addr_to_tx[addr_to_tx["input_address"].isin(["13c5bD3yay8QaJGbHrW8WjGYg8ekCCxz5q"])]
# Out:
#                             input_address       txId
# 64156  13c5bD3yay8QaJGbHrW8WjGYg8ekCCxz5q  224254822

# %%
tx_to_addr[tx_to_addr["output_address"].isin(["13c5bD3yay8QaJGbHrW8WjGYg8ekCCxz5q"])]
# Out:
#              txId                      output_address
# 101458  223909678  13c5bD3yay8QaJGbHrW8WjGYg8ekCCxz5q

# %%
user_to_min_class = users_with_classes.groupby("userId")["class"].min().reset_index()
user_to_min_class.to_csv("../dataset/custom/UserClasses.csv", index=False)
user_to_min_class["class"].value_counts()
# Out:
# class
# 3    408435
# 2    155083
# 1      5995
# Name: count, dtype: int64

# %%
addr_to_class["class"].value_counts()
# Out:
# class
# 3    557588
# 2    251088
# 1     14266
# Name: count, dtype: int64

# %% [markdown]
# # Соберем полную таблицу фичей пользователей

# %%
user_to_addr_cnt = pd.read_csv("../dataset/custom/AddrUser.csv") \
    .groupby("userId")["addrId"] \
    .nunique() \
    .reset_index() \
    .rename({"addrId": "addr_cnt"}, axis=1)
user_to_addr_cnt.head()
# Out:
#    userId  addr_cnt
# 0       1         1
# 1       2         1
# 2       3         1
# 3       4      5656
# 4       5         1

# %%
user_to_outcoming_tx_cnt = pd.read_csv("../dataset/custom/UserTx.csv") \
    .groupby("userId")["txId"] \
    .nunique() \
    .reset_index() \
    .rename({"txId": "outcoming_tx_cnt"}, axis=1)
user_to_outcoming_tx_cnt.head()
# Out:
#    userId  outcoming_tx_cnt
# 0       2                 1
# 1       4               167
# 2      11                 1
# 3      12                 1
# 4      13                 1

# %%
user_to_incoming_tx_cnt = pd.read_csv("../dataset/custom/TxUser.csv") \
    .groupby("userId")["txId"] \
    .nunique() \
    .reset_index() \
    .rename({"txId": "incoming_tx_cnt"}, axis=1)
user_to_incoming_tx_cnt.head()
# Out:
#    userId  incoming_tx_cnt
# 0       1                1
# 1       2                5
# 2       3                1
# 3       4             4110
# 4       5                1

# %%
user_to_incoming_users_cnt = pd.read_csv("../dataset/custom/UserUser.csv") \
    .groupby("outputUserId")["inputUserId"] \
    .nunique() \
    .reset_index() \
    .rename({"outputUserId": "userId", "inputUserId": "input_users_cnt"}, axis=1)
user_to_incoming_users_cnt.head()
# Out:
#    userId  input_users_cnt
# 0       1                1
# 1       2                5
# 2       3                1
# 3       4             3546
# 4       5                1

# %%
user_to_outcoming_users_cnt = pd.read_csv("../dataset/custom/UserUser.csv") \
    .groupby("inputUserId")["outputUserId"] \
    .nunique() \
    .reset_index() \
    .rename({"inputUserId": "userId", "outputUserId": "output_users_cnt"}, axis=1)
user_to_outcoming_users_cnt.head()
# Out:
#    userId  output_users_cnt
# 0       2                 1
# 1       4               215
# 2      11                 2
# 3      12                 1
# 4      13                 2

# %%
def merge_dfs(l, r, field_to_coalesce=None):
    res = pd.merge(
        left=l,
        right=r,
        on="userId",
        how="left",
    )
    if field_to_coalesce:
        res[field_to_coalesce] = res[field_to_coalesce].fillna(0)
    return res

user_data = merge_dfs(user_to_addr_cnt, user_to_outcoming_tx_cnt, field_to_coalesce="outcoming_tx_cnt")
user_data = merge_dfs(user_data, user_to_incoming_tx_cnt, field_to_coalesce="incoming_tx_cnt")
user_data = merge_dfs(user_data, user_to_incoming_users_cnt, field_to_coalesce="input_users_cnt")
user_data = merge_dfs(user_data, user_to_outcoming_users_cnt, field_to_coalesce="output_users_cnt")
user_data = merge_dfs(user_data, pd.read_csv("../dataset/custom/UserClasses.csv"))



user_data.to_csv("../dataset/custom/UserData_Small.csv", index=False)

# %%
wallets_features = pd.read_csv("../dataset/Elliptic++ Dataset/wallets_features.csv")
wallets_features = pd.merge(
    left=wallets_features,
    right=addr_to_user,
    left_on="address",
    right_on="addrId",
    how="left",
)
wallets_features
# Out:
#                                     address  Time step  num_txs_as_sender  \
# 0         111112TykSw72ztDN2WJger4cynzWYC5w         25                0.0
# 1         1111DAYXhoxZx2tsRnzimfozo783x1yC2         25                0.0
# 2         1111DAYXhoxZx2tsRnzimfozo783x1yC2         29                0.0
# 3         1111DAYXhoxZx2tsRnzimfozo783x1yC2         39                0.0
# 4         1111DAYXhoxZx2tsRnzimfozo783x1yC2         39                0.0
# ...                                     ...        ...                ...
# 1268255  3R2Uw5MRdSSigp8AjfT7K5es6Hupm4qLSq         31                1.0
# 1268256  3R2VBFbqHGC4bQ7b4ixN4jZTdv7RMbEYtf         44                0.0
# 1268257  3R2WFmRwbDeo3rMVVu5J3jjMxAuQYYWAid          9                0.0
# 1268258  3R2WTZGYLmbJQyoDSBftJsPRvF1mSEtkh6          3                0.0
# 1268259  3R2bm6iqbzcVpEeFCSFarS56b56QfjyiSW          9                1.0
#
#          num_txs_as receiver  first_block_appeared_in  last_block_appeared_in  \
# 0                        1.0                 439586.0                439586.0
# 1                        8.0                 439589.0                485959.0
# 2                        8.0                 439589.0                485959.0
# 3                        8.0                 439589.0                485959.0
# 4                        8.0                 439589.0                485959.0
# ...                      ...                      ...                     ...
# 1268255                  1.0                 451684.0                451685.0
# 1268256                  1.0                 477895.0                477895.0
# 1268257                  1.0                 407342.0                407342.0
# 1268258                  1.0                 395235.0                395235.0
# 1268259                  0.0                 407333.0                407333.0
#
#          lifetime_in_blocks  total_txs  first_sent_block  \
# 0                       0.0        1.0               0.0
# 1                   46370.0        8.0               0.0
# 2                   46370.0        8.0               0.0
# 3                   46370.0        8.0               0.0
# 4                   46370.0        8.0               0.0
# ...                     ...        ...               ...
# 1268255                 1.0        2.0          451685.0
# 1268256                 0.0        1.0               0.0
# 1268257                 0.0        1.0               0.0
# 1268258                 0.0        1.0               0.0
# 1268259                 0.0        1.0          407333.0
#
#          first_received_block  ...  blocks_btwn_output_txs_mean  \
# 0                    439586.0  ...                     0.000000
# 1                    439589.0  ...                  6624.285714
# 2                    439589.0  ...                  6624.285714
# 3                    439589.0  ...                  6624.285714
# 4                    439589.0  ...                  6624.285714
# ...                       ...  ...                          ...
# 1268255              451684.0  ...                     0.000000
# 1268256              477895.0  ...                     0.000000
# 1268257              407342.0  ...                     0.000000
# 1268258              395235.0  ...                     0.000000
# 1268259                   0.0  ...                     0.000000
#
#          blocks_btwn_output_txs_median  num_addr_transacted_multiple  \
# 0                                  0.0                           0.0
# 1                               8060.0                           0.0
# 2                               8060.0                           0.0
# 3                               8060.0                           0.0
# 4                               8060.0                           0.0
# ...                                ...                           ...
# 1268255                            0.0                           0.0
# 1268256                            0.0                           0.0
# 1268257                            0.0                           0.0
# 1268258                            0.0                           0.0
# 1268259                            0.0                           0.0
#
#          transacted_w_address_total  transacted_w_address_min  \
# 0                              24.0                       1.0
# 1                               8.0                       1.0
# 2                               8.0                       1.0
# 3                               8.0                       1.0
# 4                               8.0                       1.0
# ...                             ...                       ...
# 1268255                         3.0                       1.0
# 1268256                         1.0                       1.0
# 1268257                         1.0                       1.0
# 1268258                         1.0                       1.0
# 1268259                         1.0                       1.0
#
#          transacted_w_address_max  transacted_w_address_mean  \
# 0                             1.0                        1.0
# 1                             1.0                        1.0
# 2                             1.0                        1.0
# 3                             1.0                        1.0
# 4                             1.0                        1.0
# ...                           ...                        ...
# 1268255                       1.0                        1.0
# 1268256                       1.0                        1.0
# 1268257                       1.0                        1.0
# 1268258                       1.0                        1.0
# 1268259                       1.0                        1.0
#
#          transacted_w_address_median                              addrId  \
# 0                                1.0   111112TykSw72ztDN2WJger4cynzWYC5w
# 1                                1.0   1111DAYXhoxZx2tsRnzimfozo783x1yC2
# 2                                1.0   1111DAYXhoxZx2tsRnzimfozo783x1yC2
# 3                                1.0   1111DAYXhoxZx2tsRnzimfozo783x1yC2
# 4                                1.0   1111DAYXhoxZx2tsRnzimfozo783x1yC2
# ...                              ...                                 ...
# 1268255                          1.0  3R2Uw5MRdSSigp8AjfT7K5es6Hupm4qLSq
# 1268256                          1.0  3R2VBFbqHGC4bQ7b4ixN4jZTdv7RMbEYtf
# 1268257                          1.0  3R2WFmRwbDeo3rMVVu5J3jjMxAuQYYWAid
# 1268258                          1.0  3R2WTZGYLmbJQyoDSBftJsPRvF1mSEtkh6
# 1268259                          1.0  3R2bm6iqbzcVpEeFCSFarS56b56QfjyiSW
#
#          userId
# 0        244669
# 1          8814
# 2          8814
# 3          8814
# 4          8814
# ...         ...
# 1268255   28030
# 1268256  191828
# 1268257  566274
# 1268258  222919
# 1268259    1119
#
# [1268260 rows x 59 columns]

# %%
wallets_features_agg = wallets_features \
    .groupby("userId") \
    .agg({
        "Time step": "nunique",
        "btc_transacted_total": "sum",
        "btc_sent_total": "sum",
        "btc_received_total": "sum",
        "btc_sent_median": "median",
        "btc_received_median": "median",
    }) \
    .reset_index() \
    .rename(columns={
        "Time step": "active_time_steps_cnt",
        "txId": "incoming_tx_cnt",
    })
wallets_features_agg.head()
# Out:
#    userId  active_time_steps_cnt  btc_transacted_total  btc_sent_total  \
# 0       1                      1              0.004675        0.000000
# 1       2                      1              0.060000        0.030000
# 2       3                      1              0.004900        0.000000
# 3       4                     26          23970.064106    12838.606215
# 4       5                      1              0.007039        0.000000
#
#    btc_received_total  btc_sent_median  btc_received_median
# 0            0.004675          0.00000             0.004675
# 1            0.030000          0.00000             0.000800
# 2            0.004900          0.00000             0.004900
# 3        11131.457891          0.03835             0.015823
# 4            0.007039          0.00000             0.007039

# %%
user_to_outcoming_addr_cnt = pd.read_csv("../dataset/custom/UserTx.csv") \
    .merge(
        pd.read_csv("../dataset/Elliptic++ Dataset/TxAddr_edgelist.csv"),
        how="left",
        left_on="txId",
        right_on="txId",
    ) \
    .groupby("userId")["output_address"] \
    .nunique() \
    .reset_index() \
    .rename({"userId": "userId", "output_address": "interracted_output_address_cnt"}, axis=1)

user_to_incoming_addr_cnt = pd.read_csv("../dataset/custom/TxUser.csv") \
    .merge(
        pd.read_csv("../dataset/Elliptic++ Dataset/AddrTx_edgelist.csv"),
        how="left",
        left_on="txId",
        right_on="txId",
    ) \
    .groupby("userId")["input_address"] \
    .nunique() \
    .reset_index() \
    .rename({"userId": "userId", "input_address": "interracted_input_address_cnt"}, axis=1)


user_to_incoming_addr_cnt
# Out:
#         userId  interracted_input_address_cnt
# 0            1                              1
# 1            2                              5
# 2            3                              1
# 3            4                          11097
# 4            5                              1
# ...        ...                            ...
# 531662  569509                              8
# 531663  569510                              1
# 531664  569511                              2
# 531665  569512                              2
# 531666  569513                              5
#
# [531667 rows x 2 columns]

# %%
user_data_populated = merge_dfs(user_data, wallets_features_agg)
user_data_populated = merge_dfs(user_data_populated, user_to_outcoming_addr_cnt, "interracted_output_address_cnt")
user_data_populated = merge_dfs(user_data_populated, user_to_incoming_addr_cnt, "interracted_input_address_cnt")

user_data_populated.to_csv("../dataset/custom/UserData.csv", index=False)

# %% [markdown]
# **Add fees info**

# %%
tx_to_fee = pd.read_csv("../dataset/Elliptic++ Dataset/txs_features.csv")[["txId", "fees"]]

user_to_tx = pd.read_csv("../dataset/custom/UserTx.csv")

tx_to_fee = tx_to_fee.groupby('txId')['fees'].agg(['sum', 'mean', "min"]).reset_index() \
    .rename(columns={"sum": "fees_total", "mean": "fees_mean", "min": "fees_min"})

user_to_fees = user_to_tx \
    .merge(
        tx_to_fee,
        how="left",
        left_on="txId",
        right_on="txId",
    ) \
    .groupby("userId") \
    .agg({
        "fees_total": "sum",
        "fees_mean": "mean",
        "fees_min": "min",
    }) \
    .reset_index()
user_to_fees
# Out:
#         userId  fees_total  fees_mean  fees_min
# 0            2    0.000200   0.000200  0.000200
# 1            4    1.838772   0.011011  0.000182
# 2           11    0.000100   0.000100  0.000100
# 3           12    0.002932   0.002932  0.002932
# 4           13    0.000147   0.000147  0.000147
# ...        ...         ...        ...       ...
# 146778  569484    0.000147   0.000147  0.000147
# 146779  569488    0.001095   0.001095  0.001095
# 146780  569489    0.000200   0.000200  0.000200
# 146781  569495    0.000136   0.000136  0.000136
# 146782  569505    0.000300   0.000300  0.000300
#
# [146783 rows x 4 columns]

# %%
user_data_populated_with_fees = merge_dfs(user_data_populated, user_to_fees)
user_data_populated_with_fees["fees_total"] = user_data_populated_with_fees["fees_total"].fillna(0)
user_data_populated_with_fees["fees_mean"] = user_data_populated_with_fees["fees_mean"].fillna(0)
user_data_populated_with_fees["fees_min"] = user_data_populated_with_fees["fees_min"].fillna(0)
user_data_populated_with_fees.to_csv("../dataset/custom/UserData.csv", index=False)

# %%
def gini_coefficient(values):
    sorted_values = sorted(values)
    n = len(values)
    cumsum = sum([(i+1) * val for i, val in enumerate(sorted_values)])
    return (2 * cumsum) / (n * sum(values)) - (n + 1) / n

def safe_gini_coefficient(values):
    if len(values) < 2:
        return 0
    if sum(values) == 0:
        return np.nan
    try:
        return gini_coefficient(values)
    except:
        return np.nan
user_to_ts_gini = wallets_features.groupby('userId')['Time step'].apply(safe_gini_coefficient)
user_to_ts_gini = user_to_ts_gini.reset_index().rename(columns={"Time step": "overall_activity_coef"})

# %%
user_to_ts_gini.value_counts()
# Out:
# userId  overall_activity_coef
# 1       0.000000                 1
# 379678  0.000000                 1
# 379672  0.000000                 1
# 379673  0.009434                 1
# 379674  0.023810                 1
#                                 ..
# 189834  0.000000                 1
# 189833  0.000000                 1
# 189832  0.000000                 1
# 189831  0.000000                 1
# 569513  0.000000                 1
# Name: count, Length: 569513, dtype: int64

# %%
user_data_populated_with_gini = merge_dfs(user_data_populated, user_to_ts_gini)

# %%
# wallets_features = pd.read_csv("../dataset/Elliptic++ Dataset/wallets_features.csv")
tx_to_fee = pd.read_csv("../dataset/Elliptic++ Dataset/txs_features.csv")[["txId", "fees", "Time step"]]
ts_to_fees = tx_to_fee.groupby('Time step')['fees'].agg(['median', 'mean']).reset_index() \
    .rename(columns={"median": "fees_in_ts_median", "mean": "fees_in_ts_mean"})

tx_to_fee_sum = tx_to_fee.groupby(['txId', "Time step"])['fees'].agg(['sum']).reset_index() \
    .rename(columns={"sum": "tx_fees_sum"})
tx_to_fee_sum
user_to_fees_by_ts = user_to_tx \
    .merge(
        tx_to_fee_sum,
        how="left",
        left_on="txId",
        right_on="txId",
    ) \
    .groupby(["userId", "Time step"])["tx_fees_sum"] \
    .agg(['mean', "median"]).reset_index() \
    .rename(columns={"mean": "user_tx_fees_mean", "median": "user_tx_sum_median"})
user_to_fees_by_ts = user_to_fees_by_ts \
    .merge(
        ts_to_fees,
        how="left",
        left_on="Time step",
        right_on="Time step",
    )
user_to_fees_by_ts["user_mean_fees_to_ts_fees_share"] = user_to_fees_by_ts["user_tx_fees_mean"] / user_to_fees_by_ts["fees_in_ts_mean"]
user_to_fees_by_ts
# Out:
#         userId  Time step  user_tx_fees_mean  user_tx_sum_median  \
# 0            2          4           0.000200            0.000200
# 1            4         23           0.001932            0.001923
# 2            4         24           0.001315            0.001215
# 3            4         25           0.002931            0.002801
# 4            4         26           0.007804            0.006590
# ...        ...        ...                ...                 ...
# 151059  569484         32           0.000147            0.000147
# 151060  569488         40           0.001095            0.001095
# 151061  569489         11           0.000200            0.000200
# 151062  569495          8           0.000136            0.000136
# 151063  569505          6           0.000300            0.000300
#
#         fees_in_ts_median  fees_in_ts_mean  user_mean_fees_to_ts_fees_share
# 0                0.000100         0.000205                         0.977704
# 1                0.000200         0.000376                         5.140958
# 2                0.000204         0.000424                         3.099915
# 3                0.000175         0.000480                         6.105331
# 4                0.000237         0.000613                        12.729608
# ...                   ...              ...                              ...
# 151059           0.000358         0.000564                         0.260580
# 151060           0.000887         0.002286                         0.478945
# 151061           0.000100         0.000228                         0.877566
# 151062           0.000200         0.000464                         0.292087
# 151063           0.000300         0.000340                         0.882642
#
# [151064 rows x 7 columns]

# %%
user_to_fees_info = user_to_fees_by_ts \
    .groupby(["userId"])["user_mean_fees_to_ts_fees_share"] \
    .agg(['mean', "min", "max"]).reset_index() \
    .rename(columns={
        "mean": "user_ts_fees_share_mean",
        "min": "user_ts_fees_share_min",
        "max": "user_ts_fees_share_max",
    })
user_to_fees_info
# Out:
#         userId  user_ts_fees_share_mean  user_ts_fees_share_min  \
# 0            2                 0.977704                0.977704
# 1            4                 9.835605                3.099915
# 2           11                 0.552181                0.552181
# 3           12                16.190508               16.190508
# 4           13                 0.310192                0.310192
# ...        ...                      ...                     ...
# 146778  569484                 0.260580                0.260580
# 146779  569488                 0.478945                0.478945
# 146780  569489                 0.877566                0.877566
# 146781  569495                 0.292087                0.292087
# 146782  569505                 0.882642                0.882642
#
#         user_ts_fees_share_max
# 0                     0.977704
# 1                    19.605217
# 2                     0.552181
# 3                    16.190508
# 4                     0.310192
# ...                        ...
# 146778                0.260580
# 146779                0.478945
# 146780                0.877566
# 146781                0.292087
# 146782                0.882642
#
# [146783 rows x 4 columns]

# %%
user_data_populated_with_gini_and_ts_fees = merge_dfs(user_data_populated_with_gini, user_to_fees_info)
# user_data_populated_with_gini_and_ts_fees.head(15)
user_data_populated_with_gini_and_ts_fees["user_ts_fees_share_mean"] = user_data_populated_with_gini_and_ts_fees["user_ts_fees_share_mean"].fillna(0)
user_data_populated_with_gini_and_ts_fees["user_ts_fees_share_min"] = user_data_populated_with_gini_and_ts_fees["user_ts_fees_share_min"].fillna(0)
user_data_populated_with_gini_and_ts_fees["user_ts_fees_share_max"] = user_data_populated_with_gini_and_ts_fees["user_ts_fees_share_max"].fillna(0)

# %%
user_data_populated_with_gini_and_ts_fees.to_csv("../dataset/custom/UserData.csv", index=False)

# %%
user_to_whole_fee_cnt = user_to_tx \
    .merge(
        tx_to_fee_sum,
        how="left",
        left_on="txId",
        right_on="txId",
    ) \
    .drop(["txId", "Time step"], axis=1)
user_to_whole_fee_cnt["whole_fee_4"] = (
    np.floor(user_to_whole_fee_cnt["tx_fees_sum"] * (10**4)) == 
    user_to_whole_fee_cnt["tx_fees_sum"] * (10**4)
).astype(int)
user_to_whole_fee_cnt["whole_fee_5"] = (
    np.floor(user_to_whole_fee_cnt["tx_fees_sum"] * (10**4)) == 
    user_to_whole_fee_cnt["tx_fees_sum"] * (10**4)
).astype(int)
user_to_whole_fee_cnt["whole_fee_6"] = (
    np.floor(user_to_whole_fee_cnt["tx_fees_sum"] * (10**4)) == 
    user_to_whole_fee_cnt["tx_fees_sum"] * (10**4)
).astype(int)
user_to_whole_fee_cnt = user_to_whole_fee_cnt.groupby("userId") \
    .agg({
        "whole_fee_4": "sum",
        "whole_fee_5": "sum",
        "whole_fee_6": "sum",
    }) \
    .reset_index()
user_data_with_whole_fees = merge_dfs(user_data_populated_with_gini_and_ts_fees, user_to_whole_fee_cnt)
user_data_with_whole_fees["whole_fee_4"] = user_data_with_whole_fees["whole_fee_4"].fillna(0)
user_data_with_whole_fees["whole_fee_5"] = user_data_with_whole_fees["whole_fee_5"].fillna(0)
user_data_with_whole_fees["whole_fee_6"] = user_data_with_whole_fees["whole_fee_6"].fillna(0)

user_data_with_whole_fees.to_csv("../dataset/custom/UserData.csv", index=False)
